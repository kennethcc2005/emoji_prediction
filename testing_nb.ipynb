# %%
import pandas as pd 
import numpy as np
import json

# %%
df = pd.read_csv('data/emoji_table.txt', encoding='utf-8', index_col=0)

# %%
df['count']=0

# %%
emoji_dict = df['count'].to_dict()

# %%
df.index[0]
# Out:
# u'\U0001f600'

# %%
for key in emoji_dict.keys():
    print key
    break
# Out:
# 🇮🇨

# %%
len(emoji_dict.keys())
# Out:
# 1604

# %%
tweets_data_path = 'data/twitter_dump_small.txt'

tweets_data = []

# parse tweets into json and store it in list
tweets_file = open(tweets_data_path, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
print len(xx.split()[-1])

str(xx.split()[-1])[-1]
# Out:
# 14
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-34-65dd71fc75e1> in <module>()
#       1 print len(xx.split()[-1])
#       2
# ----> 3 str(xx.split()[-1])[-1]
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 10-13: ordinal not in range(128)

# %%
z = xx.replace(u'\U0001f60a', u' \U0001f60a ')

# %%
z.split()
# Out:
# [u"I've",
#  u'enjoyed',
#  u'this',
#  u'basketball',
#  u'season',
#  u'though....the',
#  u'journey',
#  u'was',
#  u'sooo',
#  u'fun',
#  u'and',
#  u'exciting',
#  u'while',
#  u'it',
#  u'lasted....',
#  u'\U0001f60a',
#  u'\U0001f60a',
#  u'\U0001f49c\U0001f49b']

# %%
xx = tweets_data[13]['text']

# %%
for i, tweepy in enumerate(tweets_data):
    
    print tweepy['text']
    
    if i == 100:
        break
# Out:
# RT @1047KDUK: May you have as much fun with your weekend as Chris Martin and Blue Ivy are in these superbowl backstage pics https://t.co/fk…
# RT @SUPERELFS06: Preview/160305 LeeTeuk, Kangin &amp; HeeChul having fun at ICN ^^~  going to Shanghai ©orianejewel https://t.co/EBeIheowXx
# @Ronnie2K @LD2K your game is so shit I literally took it out mid game &amp; threw it out in the other room. actually had fun a couple days wtf
# RT @ShanSossamon: I miss all involved with this special movie &lt;3 https://t.co/VX1RLFITa1
# RT @TheObamaDiary: Fun Fact: In Clinton v Dole 96 presidential election, guess who Cenk Uygur voted for (he was 26)?
#
# Yep, Dole
#
# His Clinto…
# Having fun playing #CSRRacing for iOS, why not join me for FREE?
# https://t.co/PYVqtAKcxA
# RT @j15hooper: I wish I was a little kid again. No worries. No problems. No drama. No responsibility. Just playing and having fun.
# Photo - Fridays spent with friends are always fun, especially when Pudge is in town! #TexasRangers https://t.co/ULQx8nm2wP
# @DayAlabaster @Slate its all part of twitter fun #clintonmustgo
# https://t.co/ddIOlGP5CI https://t.co/1FPLncO2cY https://t.co/TNmZnZPLnu ...
# @RollingStone
# Cjclxucsy accused of a mineral water and friends and family members who are you guys doing anything fun with your gift
# @SubmissiveLexi your going to have Fun with that, when you get to use it.
# thank you shaniaaa https://t.co/zmMutSFgR8
# I've enjoyed this basketball season though....the journey was sooo fun and exciting while it lasted....😊😊💜💛
# I got my liptifulinternational in today. I'm having so much fun playing with this thing. #plump… https://t.co/iKzNga49ve
# my idea of a fun Friday night is rearranging the kitchen cabinets with @Fricke1947.  😘
# %%
diversity_df = pd.read_csv('data/diversity_table.txt', encoding='utf-8', index_col=0)
diversity_df['count'] = 0

# %%
dd =diversity_df.to_dict()['count'].keys()

# %%
list(dd)[0]
# Out:
# u'\U0001f483'

# %%
len(dd)
# Out:
# 384

# %%
for key in emoji_dict.keys():
    if key in xx:
        print key, 'here'
# Out:
# 😊 here
# 💛 here
# 💜 here

# %% [markdown]
# # Tweet Parsing

# %%
from pyspark import SparkContext
import json
import nltk
import re
from collections import Counter, defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from __future__ import division
from string import punctuation

# %%
sc = SparkContext()

# %%
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()

# %%
REGEX = u"[\U00002712\U00002714\U00002716\U0000271d\U00002721\U00002728\U00002733\U00002734\U00002744\U00002747\U0000274c\U0000274e\U00002753-\U00002755\U00002757\U00002763\U00002764\U00002795-\U00002797\U000027a1\U000027b0\U000027bf\U00002934\U00002935\U00002b05-\U00002b07\U00002b1b\U00002b1c\U00002b50\U00002b55\U00003030\U0000303d\U0001f004\U0001f0cf\U0001f170\U0001f171\U0001f17e\U0001f17f\U0001f18e\U0001f191-\U0001f19a\U0001f201\U0001f202\U0001f21a\U0001f22f\U0001f232-\U0001f23a\U0001f250\U0001f251\U0001f300-\U0001f321\U0001f324-\U0001f393\U0001f396\U0001f397\U0001f399-\U0001f39b\U0001f39e-\U0001f3f0\U0001f3f3-\U0001f3f5\U0001f3f7-\U0001f4fd\U0001f4ff-\U0001f53d\U0001f549-\U0001f54e\U0001f550-\U0001f567\U0001f56f\U0001f570\U0001f573-\U0001f579\U0001f587\U0001f58a-\U0001f58d\U0001f590\U0001f595\U0001f596\U0001f5a5\U0001f5a8\U0001f5b1\U0001f5b2\U0001f5bc\U0001f5c2-\U0001f5c4\U0001f5d1-\U0001f5d3\U0001f5dc-\U0001f5de\U0001f5e1\U0001f5e3\U0001f5ef\U0001f5f3\U0001f5fa-\U0001f64f\U0001f680-\U0001f6c5\U0001f6cb-\U0001f6d0\U0001f6e0-\U0001f6e5\U0001f6e9\U0001f6eb\U0001f6ec\U0001f6f0\U0001f6f3\U0001f910-\U0001f918\U0001f980-\U0001f984\U0001f9c0\U00003297\U00003299\U000000a9\U000000ae\U0000203c\U00002049\U00002122\U00002139\U00002194-\U00002199\U000021a9\U000021aa\U0000231a\U0000231b\U00002328\U00002388\U000023cf\U000023e9-\U000023f3\U000023f8-\U000023fa\U000024c2\U000025aa\U000025ab\U000025b6\U000025c0\U000025fb-\U000025fe\U00002600-\U00002604\U0000260e\U00002611\U00002614\U00002615\U00002618\U0000261d\U00002620\U00002622\U00002623\U00002626\U0000262a\U0000262e\U0000262f\U00002638-\U0000263a\U00002648-\U00002653\U00002660\U00002663\U00002665\U00002666\U00002668\U0000267b\U0000267f\U00002692-\U00002694\U00002696\U00002697\U00002699\U0000269b\U0000269c\U000026a0\U000026a1\U000026aa\U000026ab\U000026b0\U000026b1\U000026bd\U000026be\U000026c4\U000026c5\U000026c8\U000026ce\U000026cf\U000026d1\U000026d3\U
1e6\U0001f1e8\U0001f1e9\U0001f1eb-\U0001f1ed\U0001f1ef-\U0001f1f4\U0001f1f7\U0001f1f9\U0001f1fb\U0001f1fc\U0001f1ff]|\U0001f1fa[\U0001f1e6\U0001f1ec\U0001f1f2\U0001f1f8\U0001f1fe\U0001f1ff]|\U0001f1fb[\U0001f1e6\U0001f1e8\U0001f1ea\U0001f1ec\U0001f1ee\U0001f1f3\U0001f1fa]|\U0001f1fc[\U0001f1eb\U0001f1f8]|\U0001f1fd\U0001f1f0|\U0001f1fe[\U0001f1ea\U0001f1f9]|\U0001f1ff[\U0001f1e6\U0001f1f2\U0001f1fc]|[0-9*#]\ufe0f\u20e3"

# %%
def tweet_process(tweet):
    KEY = 'text'
    try:
        tw = json.loads(tweet.strip())
        if KEY not in tw or tw['lang']!= 'en':
            return None
        return tw

    except Exception as e:
        return None

# %%
def emoji_preprocess(tweet, predict=False):
    # add space before and after space
    for emoji in re.findall(REGEX, tweet):
        tweet = tweet.replace(emoji, ' ' + emoji + ' ')

    # tokenize and remove rt and @ and https://
    tweet = re.sub('\?', '', tweet)
    tweet = re.sub('\.', '', tweet)
    tweet = re.sub(',', '', tweet)
    tweet = re.sub('!', '', tweet)

    tweet_tmp = [ snowball.stem(wd.strip(punctuation)) for wd in tweet.strip('rt').split() if not wd.startswith('@') and not wd.startswith('http') and not wd.startswith('#') ]

    if predict:
        tweet_token = ['<s>'] + tweet_tmp
    else:
        tweet_token = ['<s>'] + tweet_tmp + ['</s>']

    return tweet_token

# %%
def bigrams(tweet):
    return [ ((w1,), w2) for w1, w2 in nltk.bigrams(tweet)]

# %%
def trigrams(tweet):
    # generate trigrams from tweets
    return [((w1, w2), w3) for w1, w2, w3 in nltk.trigrams(tweet)]

# %%
def quadgrams(tweet):
    #generate n grams
    return [((w1, w2, w3), w4) for w1, w2, w3, w4 in nltk.ngrams(tweet, 4)]

# %%
tweets =  sc.textFile('data/twitter_dump_small.txt')\
.filter(lambda tw: len(tw)>1)\
.filter(lambda tw: 'created_at' in tw)\
.map(tweet_process)\
.filter(lambda tw: tw != None)\
.map(lambda tw: tw['text'].lower() )\

# %%
tweets_tokens = tweets.map(emoji_preprocess)

# %%
bigram_count = tweets.map(emoji_preprocess).flatMap(bigrams).map(lambda bg: (bg, 1)).reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).collect()

# %%
bigram_dict = tweets.map(emoji_preprocess).flatMap(bigrams).map(lambda bg: (bg, 1))\
.reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).map(lambda (((w0,), w1), cnt): (w0, w1, cnt) ).collect()

# %%
trigram_count = tweets.map(emoji_preprocess).flatMap(trigrams).map(lambda bg: (bg, 1)).reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).map(lambda (((w0, w1), w2), cnt) : ((w0, w1,) w2, cnt) ).collect()
# Out:
#   File "<ipython-input-155-77b2879257ed>", line 1
#     trigram_count = tweets.map(emoji_preprocess).flatMap(trigrams).map(lambda bg: (bg, 1)).reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).map(lambda (((w0, w1), w2), cnt) : ((w0, w1,) w2, cnt) ).collect()
#                                                                                                                                                                                     ^
# SyntaxError: invalid syntax

# %%
zip(*bigram_dict)[0]
# Out:
# (u'the',
#  u'do',
#  u'today',
#  u'friday',
#  '<s>',
#  u'spiderman',
#  u'day',
#  u'pbs',
#  u'releas',
#  '<s>',
#  u'\U0001f600',
#  u'excit',
#  u'two',
#  u'internet',
#  u'back',
#  u'accept',
#  u'treat',
#  u'anoth',
#  u'should',
#  u'age',
#  u'that',
#  u'rav',
#  u'hank',
#  u'good',
#  u'fun',
#  u'fun',
#  u'foam',
#  u'all',
#  u'fun',
#  u'day',
#  u'',
#  u'1',
#  u'fun',
#  u'now',
#  u'knew',
#  u'to',
#  u'oday',
#  u's/o',
#  u'grandma',
#  '<s>',
#  u'fact',
#  u'\U0001f918',
#  '<s>',
#  u'out',
#  u'paint',
#  u'news',
#  u'check',
#  u'my',
#  u'be',
#  u'ry',
#  u'her',
#  u'your',
#  u'fun',
#  u'fun',
#  u'and',
#  u'get',
#  u'pleaser',
#  u'play',
#  u'fun',
#  u'my',
#  u'and\u2026',
#  u'these',
#  u"couldn't",
#  u'buddi',
#  u'omgal',
#  u'hey',
#  '<s>',
#  u'so',
#  u'saddest',
#  '<s>',
#  u'and',
#  u'help',
#  u'need',
#  u'sad',
#  u'are',
#  u'concert',
#  u'way',
#  u'msg-2',
#  u'how',
#  u'are',
#  u'\U0001f600',
#  u'barf',
#  u'me',
#  u'conserv',
#  u'staff',
#  u"doesn't",
#  u'have',
#  u'actor',
#  u'than',
#  u'wait',
#  '<s>',
#  u'o',
#  u'endless',
#  u'hey',
#  u'skype',
#  '<s>',
#  u'studio',
#  u'b',
#  u'great',
#  u'sh*t',
#  '<s>',
#  u'problem',
#  u'fun',
#  u'and',
#  u'day',
#  u'3-gun',
#  u'realli',
#  u'his',
#  u'onli',
#  u"i'm",
#  u'career',
#  u'can',
#  u'\U0001f438',
#  u'you',
#  u'loui',
#  u'insan',
#  '<s>',
#  u'processabow',
#  u'on',
#  u'ladi',
#  u'stencil',
#  u"i'll",
#  u'shot',
#  '<s>',
#  u'patron',
#  u'peopl',
#  u'my',
#  u'marketing-element',
#  u'but',
#  u'this',
#  u'cudd',
#  u'game',
#  u'seem',
#  u'you',
#  u'violenc',
#  u'to',
#  u'brave',
#  u'touch',
#  '<s>',
#  u'have',
#  u'i',
#  u'a',
#  u'look',
#  u'\U0001f602',
#  u'and',
#  u'poker',
#  u'at',
#  u'\u266b',
#  u'tomorrow',
#  u'by',
#  u'great',
#  u'to',
#  u'fun',
#  u'nearbi',
#  u'work',
#  u'to',
#  u'i',
#  u'yr',
#  u'peopl',
#  u'hometown',
#  u'was',
#  u'got',
#  u'what',
#  u'fa',
#  u'know',
#  u'dalek',
#  u'had',
#  u'3pm',
#  u'do',
#  u'came',
#  u'idea',
#  u'kau',
#  u'tonight',
#  u'time',
#  u'vote',
#  u'steinfeld',
#  u'report',
#  u'pic',
#  u'me',
#  u'\u2022',
#  u'back',
#  u'let',
#  u'send',
#  u'\U0001f409',
#  u'are',
#  u'to',
#  u'thing',
#  u'again',
#  u'you',
#  u'has',
#  u'is',
#  u'winnipeg',
#  u'and',
#  u'special',
#  u'video',
#  u'ice',
#  u'find',
#  u'experi',
#  u'too',
#  u'find',
#  u"we'r",
#  u'morph',
#  u'cushion',
#  u'emind',
#  u'replay',
#  u'hahahaha',
#  u'never',
#  u'pretti',
#  u'it',
#  u'and',
#  u'say',
#  u'one',
#  u'much',
#  u'kettl',
#  u'\U0001f44f',
#  u'vs',
#  u'laboratori',
#  u'work',
#  u'bunz',
#  u'ya',
#  u'air',
#  u'seven',
#  u'on',
#  u'of',
#  u'boy',
#  '<s>',
#  u'x',
#  u'of',
#  u'have',
#  u'by',
#  u'that',
#  u'fun',
#  u'amazon',
#  u'this',
#  u'with',
#  u'of',
#  u'fun',
#  u'realli',
#  u'ruffl',
#  u'his',
#  u'boy',
#  u'thank',
#  u'street',
#  u'3',
#  u'part',
#  u'\U0001f3fe',
#  u'out',
#  u'for',
#  '<s>',
#  u'game',
#  u'less',
#  u'if',
#  u'was',
#  u'happi',
#  u'but',
#  u'today',
#  u'suicid',
#  u'bag',
#  u'amaz',
#  '<s>',
#  '<s>',
#  u'newspap',
#  u'citi',
#  u'with',
#  '<s>',
#  u'spirit',
#  u'young',
#  u'have',
#  u'girl',
#  u'would',
#  u'galleri',
#  u'pleas',
#  u'tri',
#  u'that',
#  u'beast',
#  '<s>',
#  u'in',
#  u'leadership',
#  u'10x',
#  u'such',
#  u'ek\u2026',
#  '<s>',
#  u'low',
#  u'\u266a',
#  '<s>',
#  u'8/7c',
#  u'eye',
#  u'dog',
#  u'everi',
#  u'than',
#  '<s>',
#  u'good',
#  u'fun',
#  u'it',
#  u'heh',
#  u'play',
#  u'wud',
#  u'funsometim',
#  u'partner',
#  u'8',
#  u'my',
#  u'amp',
#  u'i',
#  u'for',
#  u'someth',
#  u'least',
#  u'moba',
#  u'they',
#  u'a',
#  u'to',
#  u'talk',
#  u'wanna',
#  u'but',
#  u'with',
#  u'youll',
#  '<s>',
#  u'you',
#  u'\ufe0f',
#  u'mom',
#  u'bobbi',
#  u'be',
#  u'someth',
#  u'your',
#  u'no',
#  u'captur',
#  u'knife',
#  u'new',
#  u'yall',
#  '<s>',
#  u'and',
#  u'game',
#  u'i',
#  u'is',
#  u'to',
#  u"don't",
#  u'friday',
#  u'of',
#  u'wish',
#  '<s>',
#  '<s>',
#  u'outta',
#  u'guessup',
#  u'grea',
#  u'kick',
#  u'real',
#  u"you'r",
#  u'least',
#  u'camp',
#  u'have',
#  u'you',
#  u'free',
#  '<s>',
#  u'bot',
#  u'bacara',
#  u'by',
#  u'\u201c@mialee1976',
#  u'is',
#  '<s>',
#  u'go',
#  u'that',
#  u'anyway',
#  u'you',
#  u'night',
#  u'noooooo',
#  u'the',
#  u'with',
#  u'with',
#  u'time',
#  u'for',
#  u'hope',
#  u'whi',
#  u'fun',
#  u'of',
#  u'\U0001f3fc',
#  u'person',
#  u'home',
#  u'nigga',
#  u'there',
#  u'the',
#  u'age',
#  '<s>',
#  u'as',
#  u'was',
#  u'\U0001f49e',
#  u'employe',
#  u'moment',
#  u'care',
#  u'the',
#  u'basketbal',
#  u'cdo',
#  u'much',
#  u'the',
#  u'all',
#  u'treat',
#  u'dead',
#  u'on',
#  u'cast/hous',
#  u'took',
#  u'she',
#  u'but',
#  u'i',
#  u'over',
#  u'in',
#  u'tryout',
#  u'feed',
#  u'laura',
#  u'\U0001f60e',
#  u'all',
#  u'have',
#  u'my',
#  u'oday',
#  u'friend',
#  u'visit',
#  u'\U0001f62c',
#  u'it',
#  u'dracula',
#  u'me',
#  u'much',
#  u'for',
#  u'with',
#  u'via',
#  u'',
#  u'all',
#  u'wors',
#  u'20',
#  u'fuck',
#  u'beauti',
#  u'lion',
#  u'all',
#  u'for',
#  u'\U0001f496',
#  u'use',
#  u'zootopia',
#  u'safe',
#  u'it',
#  u"won't",
#  u'us',
#  u'on',
#  u'too',
#  u'latex',
#  u'answer',
#  '<s>',
#  u'roseburg',
#  u'guy',
#  u'sign',
#  u'and',
#  u'laugh',
#  u'you',
#  u'awesom',
#  u'of',
#  u'tomorrow',
#  u'joke',
#  u'avail',
#  u'review',
#  u'everyon',
#  u'boot',
#  u'such',
#  '<s>',
#  u'',
#  u'\ufe0f',
#  u'omorrow',
#  u'spot',
#  u'make',
#  u'the',
#  u'w4m',
#  u'and',
#  u'fact',
#  u'now',
#  u'am',
#  u'your',
#  u'aww',
#  u'all',
#  u'for',
#  u'have',
#  u'of',
#  u"we'd",
#  u'tell',
#  u'amp',
#  u'allergi',
#  u'yes',
#  u'new',
#  '<s>',
#  u'page',
#  u'incredibox',
#  u'bout',
#  u'\U0001f432',
#  u'move',
#  u'\u27a1',
#  u'time',
#  u'like',
#  u'in',
#  u'witter',
#  u'is',
#  u'thing',
#  u'watch',
#  u'of',
#  u'half',
#  u'pics/video',
#  u'at',
#  u'someon',
#  u'fun',
#  u'me',
#  u'far',
#  u'respons',
#  u'room',
#  u'is',
#  u'a',
#  u'danc',
#  u'fun',
#  u'thank',
#  u'our',
#  u'thing',
#  u'gamesit',
#  u'concert',
#  u'be',
#  u'wire',
#  u'now',
#  u'plan',
#  u'one',
#  u'those',
#  u'm&amp;m',
#  u'internet',
#  u'nausea',
#  u'the',
#  u'same',
#  u'he',
#  u'head',
#  u'wife(in',
#  u'presidenti',
#  u'w4w',
#  u'and',
#  u'\U0001f607',
#  u'im',
#  u'love',
#  u'the',
#  u'he',
#  u'littl',
#  u'out',
#  u'and',
#  u'allow',
#  u'kilig',
#  u'fun',
#  u'commit',
#  u'ot9',
#  u'giveaway',
#  u'\U0001f643',
#  '<s>',
#  u'us/can/uk',
#  u'at',
#  u'pregam',
#  u'fun',
#  u'would',
#  u'mission',
#  u'magic',
#  u'quiz',
#  u'connect',
#  '<s>',
#  u'us',
#  u'guess',
#  u'\u2763',
#  u'at',
#  u'my',
#  u'other',
#  u'braver',
#  u'the',
#  '<s>',
#  u'soooo',
#  u'tattoo',
#  u'rather',
#  u'me',
#  u'the',
#  u"i'm",
#  u'guess',
#  u'day',
#  u'that',
#  u'and',
#  u'agre',
#  u'happi',
#  u'second',
#  u'bad',
#  u'\U0001f3fb',
#  u'in',
#  u'that',
#  u'the',
#  u'out',
#  u'rippen',
#  u'gonna',
#  u'is',
#  u'\U0001f3b6',
#  u'my',
#  u'grace',
#  u'infect',
#  u'still',
#  u'lit',
#  u"i'm",
#  u'after',
#  '<s>',
#  u'4',
#  u'much',
#  u'fun',
#  u'like',
#  u'cam',
#  u'be',
#  u'gang',
#  u'to',
#  u'hope',
#  u'that',
#  u'girl',
#  u'old',
#  u'get',
#  u'day',
#  u'him',
#  '<s>',
#  u'sweet',
#  u'keep',
#  u'it',
#  u'antic',
#  u'hide',
#  u'was',
#  u'drive',
#  u'you',
#  u'recent',
#  u'you',
#  u"you'r",
#  u'fun',
#  '<s>',
#  '<s>',
#  u'everi',
#  u'pm',
#  u'london',
#  u'\ufe0f',
#  u'hayam',
#  u'some',
#  u'back',
#  u'4',
#  u'tecktonik',
#  u'just',
#  u'portion',
#  u'is',
#  u'clear',
#  u'suck',
#  u'phone',
#  u'where',
#  u'fun',
#  u'you',
#  u'fun',
#  u'on',
#  u'fun-at',
#  u'short',
#  u'the',
#  u'for',
#  u'would',
#  u'quit',
#  u"you'r",
#  u'to',
#  u'tell',
#  u'tweet',
#  u'\U0001f44d',
#  u'excitemen',
#  u'pat',
#  u'school',
#  u'had',
#  u'fun',
#  u'a',
#  u'\U0001f4fa',
#  u'that',
#  u'in',
#  u'go',
#  u'the',
#  u'and',
#  u'tri',
#  u'tonight',
#  u'real',
#  u'japanes',
#  u'lame',
#  u'i',
#  u'if',
#  u'welp',
#  u'when',
#  u'\U0001f49e',
#  u'becom',
#  u'has',
#  u'fun',
#  u'that',
#  u'spend',
#  u'go',
#  u'carolin',
#  u'some',
#  '<s>',
#  u'sa',
#  u'gorgeous',
#  u'time',
#  u'it',
#  '<s>',
#  u'spring',
#  '<s>',
#  u'new',
#  u'for',
#  u'cute',
#  u'have',
#  u'out',
#  u'mascot',
#  u'famili',
#  u'pussi',
#  u'humoursentim\u2026',
#  u'right',
#  u'his',
#  u'drif',
#  u'read',
#  u'',
#  u'and',
#  u'you',
#  u'road',
#  u'to',
#  u'just',
#  u'year',
#  u'help',
#  u'for',
#  '<s>',
#  u'a',
#  u'hello',
#  u'it',
#  u'final',
#  u'luck',
#  u'hit',
#  u'are',
#  u'ever',
#  u'simpl',
#  u'fun',
#  u'season',
#  u'give',
#  u'tbh',
#  u'ryan',
#  u'my',
#  u'year',
#  u'miami',
#  u'fixer',
#  u'print',
#  u'i',
#  u'had',
#  u'for',
#  u'retweet',
#  u'giveaway',
#  u'anyth',
#  u'str8',
#  u'hey',
#  u'were',
#  u'rod',
#  u'these',
#  '<s>',
#  u'hectic',
#  u'assassin',
#  u'your',
#  '<s>',
#  u'creat',
#  u'water',
#  u'this',
#  u'amp',
#  u'beck',
#  u'two',
#  u'nerd',
#  u'jeff',
#  u'\ufe0f',
#  u'tough',
#  u'got',
#  u'5',
#  u'school',
#  u'austin',
#  u'myself',
#  u'shangri-la',
#  u'miss',
#  u'social',
#  u'to',
#  u'this',
#  u'a',
#  u'friday',
#  u'sat',
#  u'me',
#  '<s>',
#  u'clip',
#  u'alway',
#  u'soni',
#  u'when',
#  u'fun',
#  u'great',
#  u'adult',
#  u'good',
#  u'of',
#  u'drama',
#  u'game',
#  u'set',
#  u'\U0001f3fe',
#  u'get',
#  u'more',
#  u'of',
#  u'alway',
#  u'firstborn',
#  u'\U0001f602',
#  u'his',
#  u'hear',
#  u'15',
#  u'my',
#  u'lunch',
#  u'est',
#  u'a',
#  u'urn',
#  u'has',
#  u'she',
#  u'in',
#  u'fuck',
#  u'younow',
#  u'book--which',
#  u'hm',
#  u'potenti',
#  u'record',
#  u'follow',
#  u'anoth',
#  u'citi',
#  u'walki',
#  u'at',
#  u'say',
#  u'hi',
#  u'children',
#  u'sa',
#  u'or',
#  u'cpac',
#  u'debat',
#  u'up',
#  u'were',
#  u'south',
#  u'better',
#  u'dual',
#  u'on',
#  u'friend',
#  u'show',
#  u'no',
#  u'trooper',
#  u'if',
#  u'bottl',
#  u'the',
#  u'sleep',
#  u'more',
#  u'\U0001f611',
#  u'wish',
#  u'you',
#  u'bc',
#  u"you'r",
#  u'to',
#  u'girl',
#  u'fun',
#  u'bash',
#  u'uber',
#  u'juici',
#  '<s>',
#  u'this',
#  u"didn't",
#  u'et/c',
#  u'breath',
#  u'and',
#  u'is',
#  u'had',
#  u'court',
#  u'there',
#  u'round',
#  u'check',
#  u'vacat',
#  u'a',
#  u"they'r",
#  u'on',
#  u'realli',
#  u'my',
#  u'fun',
#  u'his',
#  u'',
#  u'a',
#  u'i',
#  u'cross',
#  u'spent',
#  u'great',
#  u'ump',
#  u'bot',
#  u'a',
#  u'time',
#  u'that',
#  u'leonard',
#  u'heard',
#  u'\U0001f44c',
#  u'cortney',
#  u'in',
#  u'2',
#  u'islamophob',
#  u'diggiti',
#  u'fun',
#  u'seem',
#  u'you',
#  u'tom',
#  u'oday',
#  u'lick',
#  u'mean',
#  u'fun',
#  u'me',
#  u'creativ',
#  u'sidelin',
#  u"i'm",
#  u'cheeki',
#  u'the',
#  u'eaton',
#  u'who',
#  u'next',
#  u'be',
#  u'to',
#  u'rawdograw',
#  '<s>',
#  u'term',
#  u'actual',
#  u'better',
#  u'joeygraceffa16',
#  u'75',
#  u'bridal',
#  u'lol',
#  u'\U0001f49a',
#  u'on',
#  u'worri',
#  u'thank',
#  u'fun',
#  u'watch',
#  u'at',
#  u'send',
#  u'p',
#  u'open',
#  u'extens',
#  u'my',
#  u'her',
#  u'\U0001f3dd',
#  u'us',
#  u'new',
#  u'yale',
#  u'effect',
#  u'of',
#  u'are',
#  u'frank',
#  u'to',
#  u'was',
#  u'member',
#  '<s>',
#  u'star',
#  u'whi',
#  u'have',
#  u'play',
#  u'you',
#  u'good',
#  u'to',
#  u'my',
#  u'twitter',
#  u'after',
#  u'\u262e',
#  u'fun',
#  u'hand',
#  u'on',
#  u'make',
#  u'a',
#  u'show',
#  u'half',
#  u'out',
#  u'bodi',
#  u'domest',
#  u'hs',
#  u'feel',
#  u'to',
#  u'your',
#  u'doubl',
#  u'particip',
#  '<s>',
#  u'back',
#  '<s>',
#  u'that',
#  u'lie',
#  u'usual',
#  u'7:30pm',
#  u"we'r",
#  u'be',
#  u'night',
#  u'rt',
#  u'fgc',
#  u'ps1',
#  '<s>',
#  u'of',
#  u'in',
#  u'search',
#  u'amp',
#  u'guy',
#  u'scroll',
#  u'anyth',
#  u'there',
#  u'my',
#  u'to',
#  u'it',
#  u'5pm',
#  u'aka',
#  u'are',
#  ...)

# %%
bigram_model = pd.DataFrame(index = list(set(zip(*bigram_dict)[0])),  columns= list(set(zip(*bigram_dict)[1])))

# %%
for w0, w1, cnt in bigram_dict:
    print w0, w1, cnt
    bigram_model.loc[w0][w1] = cnt
# Out:
# the main 4
# do join 2
# today sneak 2
# friday fun 12
# <s> out 2
# spiderman amp 2
# day the 4
# pbs or 2
# releas it 2
# <s> boo 2
# 😀 fun 2
# excit highlight 2
# two decad 2
# internet meme 2
# back cos 2
# accept alcohol 2
# treat the 2
# anoth weekend 2
# should tri 2
# age 4 2
# that </s> 4
# rav 4 2
# hank to 2
# good hang 2
# fun back 2
# fun regret 2
# foam pit 2
# all of 12
# fun click 2
# day with 2
#  w4m 2
# 1 follow 2
# fun bruh 2
# now say 2
# knew they 2
# to let 2
# oday is 2
# s/o to 2
# grandma and 2
# <s> right 2
# fact dolley 2
# 🤘 🏻 12
# <s> een 2
# out free 2
# paint and 2
# news you 2
# check me 2
# my kit 2
# be stream 2
# ry  2
# her editori 2
# your question 2
# fun 🙌 2
# fun memori 4
# and powerf 2
# get them 2
# pleaser i 2
# play in 2
# fun sexi 2
# my grandma 4
# and… </s> 4
# these crunch-fre 2
# couldn't get 2
# buddi </s> 2
# omgal i 2
# hey have 2
# <s> his 22
# so fa 2
# saddest landscap 2
# <s> summer 2
# and sinc 2
# help fin 2
# need peopl 2
# sad reminisc 2
# are smoke 2
# concert  2
# way to 4
# msg-2 the 2
# how fun 6
# are and 2
# 😀 </s> 6
# barf into 2
# me treat 2
# conserv today 2
# staff and 2
# doesn't answer 2
# have depress 2
# actor walk 2
# than school 2
# wait for 10
# <s> kati 2
# o much 2
# endless fun 2
# hey a 2
# skype my 2
# <s> zootopia 4
# studio whos 2
# b pretti 2
# great detect 2
# sh*t </s> 2
# <s> new 4
# problem no 2
# fun sweati 2
# and inform 2
# day we 4
# 3-gun match 2
# realli enjoy 2
# his is 6
# onli one 6
# i'm still 2
# career 👌 2
# can have 4
# 🐸 ☕ 30
# you think 2
# loui is 2
# insan sens 2
# <s> dololo 2
# processabow everyth 2
# on game 2
# ladi if 2
# stencil add 2
# i'll be 2
# shot updat 2
# <s> day 4
# patron of 2
# peopl is 2
# my person 2
# marketing-element stencil 2
# but like 2
# this now 2
# cudd mascot 2
# mayb wayn 2
# nativ extens 2
# ipad for 2
# sweet it 2
# young team 2
# for </s> 2
# amaz day 14
# <s> freudian 2
# 😜 such 2
# twittervers </s> 2
# but we 2
# scrrame i 2
# dress and 2
# 💘 💘 4
# video make 2
# is 10x 2
# product but 2
# i'm alon 4
# that has 2
# like to 16
# the beta 2
# color corrector 2
# think of 2
# you'r do 2
# this real 2
# hahahahaha 😆 2
# fun laugh 2
# blond hav 2
# her damn 2
# fun for 6
# tho </s> 4
# just a 8
# 3 game 2
# food </s> 2
# our ek… 2
# today 😍 2
# 🍷 🍹 2
# come outta 2
# more save 2
# hope the 2
# what they 2
# vegetarian so 8
# <s> 55-55 2
# miss </s> 2
# wtf </s> 6
# shit make 2
# dead inquisit 2
# wet pussi 2
# not the 16
# improv keep 2
# <s> did 4
# a tough 2
# me im 2
# we'll miss 2
# mastermind group 4
# scratter babe 2
# leeteuk kangin 6
# univers of 2
# so sorri 2
# question for 8
# invit are 2
# 4/6/9/12 ht… 2
# not a 2
# that in 2
# to fuck 2
# wheel  2
# pitcher was 2
# than you'r 2
# format song 2
# like leia 2
# tonight fun 2
# enter to 2
# this guy 2
# the vive 2
# so great 4
# thing i'v 2
# husker and 2
# thrower ran 2
# one to 2
# 😅 🍹 2
# yourself to 2
# for tri 2
# 📷 wtf-fun-factss 2
# it tomorrow 2
# or other 2
# activ </s> 2
# play water 2
# in your 16
# snapchat worri 2
# not onli 2
# keep boogi 2
#  price 2
# fun chat 4
# nicer guy 2
# too scattershot 2
# out of 14
# makenit fun 2
# life </s> 8
# hat </s> 4
# the bball 2
# you just 4
# fri chicken 2
# make for 6
# ani other 2
# is what 2
# 💯 </s> 2
# rounder today 2
# <s> bruhhhh 2
# miss the 6
# they would 2
# quinn play 2
# this super 2
# friend with 2
# random pic 2
# miss some 2
#  </s> 36
# perfect fit 2
# too 💖 2
# ♡ </s> 4
# full swing 2
# coma </s> 2
# will you 4
# sign in 6

# %%
sp = bigram_model.to_sparse()

# %%
bigram_model.ix['sleep']['hate']
# Out:
# 0

# %%
df.loc['good']['hang'] =2

# %%
x.join(y)
# Out:
#     a   b
# a1  1 NaN

# %%
index = []
dicts = []

# %%
for (((w0,),w1) , cnt) in bigram_count:
    index.append(w0)
    dicts.append({w1:cnt})

# %%
index
# Out:
# [u'the',
#  u'do',
#  u'today',
#  u'friday',
#  '<s>',
#  u'day',
#  u'pbs',
#  u'releas',
#  '<s>',
#  u'\U0001f600',
#  u'excit',
#  u'two',
#  u'internet',
#  u'accept',
#  u'treat',
#  u'anoth',
#  u'should',
#  u'age',
#  u'that',
#  u'rav',
#  u'hank',
#  u'good',
#  u'fun',
#  u'fun',
#  u'foam',
#  u'tonight',
#  u'fun',
#  u'day',
#  u'birthday',
#  u'1',
#  u'fun',
#  u'now',
#  u'knew',
#  u'to',
#  u'oday',
#  u's/o',
#  u'grandma',
#  '<s>',
#  u'fact',
#  u'\U0001f918',
#  '<s>',
#  u'head)@kerrywashington"',
#  u'term',
#  u'paint',
#  u'news',
#  u'via:',
#  u'be',
#  u'young',
#  u'they',
#  u'your',
#  u'fun',
#  u'fun',
#  u'and',
#  u'get',
#  u'pleaser',
#  u'play',
#  u'fun',
#  u'my',
#  u'and\u2026',
#  u"couldn't",
#  u'&amp;',
#  u'deni',
#  u'hey',
#  '<s>',
#  u'so',
#  u'saddest',
#  '<s>',
#  u'help',
#  u'fun',
#  u'need',
#  u'sad',
#  u'are',
#  u'way',
#  u'msg-2',
#  u'how',
#  u'are',
#  u'\U0001f600',
#  u'barf',
#  u'me',
#  u'conserv',
#  u'staff',
#  u"doesn't",
#  u'have',
#  u'actor',
#  u'than',
#  u'wait',
#  '<s>',
#  u'o',
#  u'endless',
#  u'hey',
#  u'skype',
#  '<s>',
#  u'studio',
#  u"we'r",
#  u'great',
#  u'sh*t',
#  '<s>',
#  u'problem',
#  u'fun',
#  u'and',
#  u'day',
#  u'3-gun',
#  u'realli',
#  u'his',
#  u'onli',
#  u"i'm",
#  u'quiz',
#  u'career',
#  u'of',
#  u'fun',
#  u'can',
#  u'\U0001f438',
#  u'you',
#  u'loui',
#  u'insan',
#  '<s>',
#  u'processabow',
#  u'on',
#  u'place',
#  '<s>',
#  u'stencil',
#  u"i'll",
#  u'shot',
#  '<s>',
#  u'patron',
#  u'peopl',
#  u'my',
#  u'your',
#  u'but',
#  u'this',
#  u'cudd',
#  u'game',
#  u'seem',
#  u'you',
#  u'violenc',
#  u'to',
#  u'brave',
#  u'touch',
#  '<s>',
#  u'have',
#  u'i',
#  u'a',
#  u'about',
#  u'\U0001f602',
#  u'the',
#  u'poker',
#  u'at',
#  u'\u266b',
#  u'tomorrow',
#  u'by',
#  u'great',
#  u'to',
#  u'fun',
#  u'a',
#  u'work',
#  u'to',
#  u'i',
#  u'yr',
#  u'peopl',
#  u'hometown',
#  u'was',
#  u'got',
#  u'what',
#  u'fa',
#  u'know',
#  u'search',
#  u'had',
#  u'3pm',
#  u'do',
#  u'came',
#  u'idea',
#  u'kau',
#  u'tonight',
#  u'time',
#  u'vote',
#  u'to',
#  u'report',
#  u'pic',
#  u'me',
#  u'\u2022',
#  u'back',
#  u'the',
#  u'send',
#  u'\U0001f409',
#  u'are',
#  u'to',
#  u'thing',
#  u'again',
#  u'you',
#  u'\U0001f3fb',
#  u'is',
#  u'winnipeg',
#  u'like',
#  u'and',
#  u'of',
#  u'special',
#  u'video',
#  u'12+',
#  u'find',
#  u'experi',
#  u'creativ',
#  u'find',
#  u'morph',
#  u'scale*',
#  u'tomorrow',
#  u'in',
#  u'replay',
#  u'hahahaha',
#  u'never',
#  u'pretti',
#  u'pack',
#  u'say',
#  u'one',
#  u'much',
#  u'kettl',
#  u'a',
#  u'vs',
#  u'laboratori',
#  u'me',
#  u'air',
#  u'seven',
#  u'on',
#  u'of',
#  u'boy',
#  '<s>',
#  u'x',
#  u'of',
#  u'have',
#  u'"when',
#  u'by',
#  u'tour',
#  u'&amp;',
#  u'amazon',
#  u'this',
#  u'with',
#  u'having~"',
#  u'fun',
#  u'realli',
#  u'ruffl',
#  u'his',
#  u'boy',
#  u'thank',
#  u'street',
#  u'4)',
#  u'part',
#  u'\U0001f3fe',
#  u'out',
#  u'for',
#  '<s>',
#  u'game',
#  u'his',
#  u'attent',
#  u'was',
#  u'happi',
#  u'phone',
#  u'but',
#  u'in',
#  u'member',
#  u'bag',
#  u'parkour',
#  '<s>',
#  '<s>',
#  u'newspap',
#  u'citi',
#  u'with',
#  '<s>',
#  u'at',
#  u'~tackl',
#  u'have',
#  u'girl',
#  u'would',
#  u'brows',
#  u'pleas',
#  u'tri',
#  u'that',
#  u'beast',
#  '<s>',
#  u'in',
#  u'leadership',
#  u'10x',
#  u'such',
#  u'ek\u2026',
#  '<s>',
#  u'low',
#  u'\u266a',
#  '<s>',
#  u'8/7c',
#  u'eye',
#  u'dog',
#  u'everi',
#  u'than',
#  '<s>',
#  u'good',
#  u'fun',
#  u'my',
#  u'it',
#  u'heh',
#  u'play',
#  u'facts:',
#  u'wud',
#  u'\U0001f613',
#  u'funsometim',
#  u'partner',
#  u'and',
#  u'my',
#  u'i',
#  u'for',
#  u'someth',
#  u'least',
#  u'moba',
#  u'her',
#  u'a',
#  u'to',
#  u'talk',
#  u'wanna',
#  u'but',
#  u'with',
#  u'youll',
#  '<s>',
#  u'you',
#  u'\ufe0f',
#  u'mom',
#  u'"morn',
#  u'bobbi',
#  u'be',
#  u'someth',
#  u'loka',
#  u'no',
#  u'captur',
#  u'knife',
#  u'new',
#  u'yall',
#  '<s>',
#  u'though',
#  u'game',
#  u'i',
#  u'is',
#  u'tattoo',
#  u'to',
#  u"don't",
#  u'friday',
#  u'wish',
#  '<s>',
#  u'outta',
#  u'with',
#  u'grea',
#  u'real',
#  u"you'r",
#  u'least',
#  u'camp',
#  u'you',
#  u'roseburg',
#  '<s>',
#  '<s>',
#  u'bacara',
#  u'by',
#  u'&amp;',
#  u'is',
#  '<s>',
#  u'2',
#  u'go',
#  u'that',
#  u'anyway',
#  u'you',
#  u'noooooo',
#  u'the',
#  u'with',
#  u'time',
#  u'for',
#  u'hope',
#  u'whi',
#  u'of',
#  u'\U0001f3fc',
#  u'home',
#  u'nigga',
#  u'there',
#  u'the',
#  u'\U0001f40e',
#  u'age',
#  '<s>',
#  u'games:',
#  u'was',
#  u'if',
#  u'\U0001f49e',
#  u'employe',
#  u'enough"',
#  u'care',
#  u'the',
#  u'basketbal',
#  u'taco',
#  u'much',
#  u'buddi',
#  u'all',
#  u'treat',
#  u'dead',
#  u'on',
#  u'snow',
#  u'took',
#  u'she',
#  u'but',
#  u'i',
#  u'over',
#  u'in',
#  u'tryout',
#  u'feed',
#  u'your',
#  u'laura',
#  u'\U0001f60e',
#  u'all',
#  u'rod',
#  u'logic=',
#  u'my',
#  u'oday',
#  u'friend',
#  u'visit',
#  u'it',
#  u'now',
#  u'ornament',
#  u'much',
#  u'for',
#  u'with',
#  u'via',
#  u'all',
#  u'*i',
#  u'on',
#  u'wors',
#  u'everyon',
#  u'been',
#  u'fuck',
#  u'beauti',
#  '<s>',
#  u'all',
#  u'too',
#  u'\U0001f496',
#  u'use',
#  u'zootopia',
#  u'safe',
#  u'it',
#  u"won't",
#  u'us',
#  u'on',
#  u'too',
#  u'latex',
#  u'less',
#  '<s>',
#  u'guy',
#  u'sign',
#  u'and',
#  u'laugh',
#  u'you',
#  u'awesom',
#  u'of',
#  u'tomorrow',
#  u'joke',
#  u'avail',
#  u'review',
#  u'supporting\xa1',
#  u'everyon',
#  u'boot',
#  u'such',
#  '<s>',
#  u'south',
#  u'\ufe0f',
#  u'omorrow',
#  u'spot',
#  u'make',
#  u'the',
#  u'w4m',
#  u'have',
#  u'now',
#  u'am',
#  u'type',
#  u'aww',
#  u'all',
#  u'have',
#  u'for',
#  u'have',
#  u'of',
#  u"we'd",
#  u'-',
#  u'tell',
#  u'yes',
#  u'new',
#  '<s>',
#  u'page',
#  u'incredibox',
#  u'bout',
#  u'\U0001f432',
#  u'move',
#  u'wire',
#  u'wheel',
#  u'time',
#  u'like',
#  u'witter',
#  u'is',
#  u'at',
#  u'watch',
#  u'of',
#  u'half',
#  u'pics/video',
#  u'someon',
#  u'fun',
#  u'me',
#  u'far',
#  u'respons',
#  u'room',
#  u'is',
#  u'peeptini',
#  u'a',
#  u'danc',
#  u'fun',
#  u'thank',
#  u'our',
#  u'hectic',
#  u'gamesit',
#  u'concert',
#  u'be',
#  u'plan',
#  u'one',
#  u'those',
#  u'm&amp;m',
#  u'chang',
#  u'nausea',
#  u'the',
#  u'same',
#  u'he',
#  u'head',
#  u'&amp;',
#  u'on',
#  u'presidenti',
#  u'vocabulari',
#  u'and',
#  u'\U0001f607',
#  u'im',
#  u'love',
#  u'the',
#  u'he',
#  u'littl',
#  u'out',
#  u'and',
#  u'allow',
#  u'kilig',
#  u'night',
#  u'commit',
#  u'day',
#  u'ot9',
#  u'giveaway',
#  u'\U0001f643',
#  '<s>',
#  u'game',
#  u'at',
#  u'pregam',
#  u'fun',
#  u'would',
#  u'mission',
#  u'magic',
#  u'connect',
#  '<s>',
#  u'us',
#  u'guess',
#  u'*make',
#  '<s>',
#  u'at',
#  u'my',
#  u'okkinderhook',
#  u'braver',
#  u'the',
#  '<s>',
#  u'soooo',
#  u'fun',
#  u'rather',
#  u'joke',
#  u'me',
#  u'the',
#  u"i'm",
#  u'guess',
#  u'day',
#  u'that',
#  u'and',
#  u'agre',
#  u'happi',
#  u'second',
#  u'to',
#  u'w/',
#  u'that',
#  u'the',
#  u'out',
#  u'rippen',
#  u'gonna',
#  u'fit',
#  u'is',
#  u'\U0001f3b6',
#  u'my',
#  u'grace',
#  u'infect',
#  u'still',
#  u'lit',
#  u"i'm",
#  u'after',
#  '<s>',
#  u'4',
#  u'much',
#  u'fun',
#  u'like',
#  u'cam',
#  u'us/can/uk)',
#  u'name',
#  u'cast/hous',
#  u'gang',
#  u'to',
#  u'hope',
#  u'that',
#  u'girl',
#  u'old',
#  u'w/',
#  u'day',
#  u'io',
#  u'sweet',
#  u'keep',
#  u'and',
#  u'hide',
#  u'was',
#  u'drive',
#  u'you',
#  u'recent',
#  u'you',
#  u"you'r",
#  u'fun',
#  '<s>',
#  '<s>',
#  u'everi',
#  u'xxx',
#  u'pm',
#  u'london',
#  u'\ufe0f',
#  u'hayam',
#  u'some',
#  u'back',
#  u'doubl',
#  u'4',
#  u'tecktonik',
#  u'just',
#  u'portion',
#  u'is',
#  u'clear',
#  u'suck',
#  u'-',
#  u'pose',
#  u'phone',
#  u'where',
#  u'fun',
#  u'you',
#  u'lol',
#  u'on',
#  u'fun-at',
#  u'the',
#  u'for',
#  u'would',
#  u'quit',
#  u"you'r",
#  u'to',
#  u'tell',
#  u'tweet',
#  u'\U0001f44d',
#  u'excitemen',
#  u'pat',
#  u'school',
#  u'had',
#  u'a',
#  u'\U0001f4fa',
#  u'that',
#  u'in',
#  u'go',
#  u'work',
#  u'the',
#  u'and',
#  u'runner',
#  u'tri',
#  u'&amp;',
#  u'real',
#  u'forev',
#  u'lame',
#  u'i',
#  u'if',
#  u'welp',
#  u'when',
#  u'\U0001f49e',
#  u'becom',
#  u'has',
#  u'fun',
#  u'that',
#  u'spend',
#  u'go',
#  u'carolin',
#  u'some',
#  u'have',
#  u'sa',
#  u'gorgeous',
#  u'time',
#  u'it',
#  '<s>',
#  u'spring',
#  '<s>',
#  u'new',
#  u'for',
#  u'cute',
#  u'have',
#  u'out',
#  u'\U0001f44f',
#  u'pussi',
#  u'humoursentim\u2026',
#  u'right',
#  u'his',
#  u'drif',
#  u'read',
#  u'pittsburgh',
#  u'and',
#  u'you',
#  u'road',
#  u'to',
#  u'just',
#  u'year',
#  u'help',
#  u'on',
#  '<s>',
#  u'a',
#  u'hello',
#  u'it',
#  u'final',
#  u'luck',
#  u'play',
#  u'fact:',
#  u'are',
#  u'ever',
#  u'simpl',
#  u'\U0001f62c',
#  u'season',
#  u'give',
#  u'tbh',
#  u'you',
#  u'ryan',
#  u'my',
#  u'year',
#  u'miami',
#  u'fixer',
#  u'print',
#  u'i',
#  u'had',
#  u'-',
#  u'for',
#  u'retweet',
#  u'giveaway',
#  u'anyth',
#  u'str8',
#  u'hey',
#  u'were',
#  u'26)',
#  u'these',
#  '<s>',
#  u'and',
#  u'assassin',
#  u'your',
#  '<s>',
#  u'creat',
#  u'water',
#  u'this',
#  u'(endangered)',
#  u'beck',
#  u'two',
#  u'with',
#  u'jeff',
#  u'\ufe0f',
#  u'tough',
#  u'got',
#  u'5',
#  u'school',
#  u'austin',
#  u'myself',
#  '<s>',
#  u'miss',
#  u'social',
#  u'concert',
#  u'a',
#  u'friday',
#  u'sat',
#  u'me',
#  '<s>',
#  u'clip',
#  u'alway',
#  u'annoy',
#  u'soni',
#  u'when',
#  u'fun',
#  u'great',
#  u'adult',
#  u'good',
#  u'drama',
#  u'&amp;',
#  u'set',
#  u'\U0001f3fe',
#  u'get',
#  u'more',
#  u'of',
#  u'alway',
#  u'firstborn',
#  u'\U0001f602',
#  '<s>',
#  u'hear',
#  u'particip',
#  u'my',
#  u'lunch',
#  u'than',
#  u'urn',
#  u'"nail',
#  u'"you',
#  '<s>',
#  u'has',
#  u'she',
#  u'in',
#  u'fuck',
#  u'400+',
#  u'book--which',
#  u'hm',
#  u'potenti',
#  u'record',
#  u'follow',
#  u'anoth',
#  u'citi',
#  u'walki',
#  u'at',
#  u'watch',
#  u'hi',
#  u'children',
#  u'sa',
#  u'or',
#  u'cpac',
#  u'debat',
#  u'up',
#  u'were',
#  u'lone',
#  u'better',
#  u'im\u2026',
#  u'relax',
#  u'friend',
#  u'show',
#  u'no',
#  u'fun',
#  u'if',
#  u'bottl',
#  u'the',
#  u'sleep',
#  u'more',
#  u'\U0001f611',
#  u'wish',
#  u'you',
#  u'bc',
#  u'to',
#  u'cool',
#  u'girl',
#  u'fun',
#  u'bash',
#  u'juici',
#  u'this',
#  u"didn't",
#  u'et/c',
#  u'day',
#  u'and',
#  u'is',
#  u'had',
#  u'this:',
#  u'court',
#  u'there',
#  u'check',
#  u'vacat',
#  u'a',
#  u"they'r",
#  u'notebook',
#  u'on',
#  u'realli',
#  u'my',
#  u'fun',
#  u'his',
#  u'other',
#  u'bts',
#  u'her)',
#  u'a',
#  u'i',
#  u"isn't",
#  u'cross',
#  u'spent',
#  u'great',
#  u'ump',
#  u'bot',
#  u'a',
#  u'time',
#  u'leonard',
#  u'heard',
#  u'\U0001f44c',
#  u'cortney',
#  u'and',
#  u'2',
#  u'when',
#  u'diggiti',
#  u'fun',
#  u'seem',
#  u'you',
#  u'ellen',
#  u'oday',
#  u'lick',
#  u'mean',
#  u'fun',
#  u'me',
#  u'round',
#  u'sidelin',
#  u'and',
#  u"i'm",
#  u'cheeki',
#  u'right',
#  u'ry',
#  u'eaton',
#  u'who',
#  u'be',
#  u'to',
#  u'rawdograw',
#  '<s>',
#  u'actual',
#  u'better',
#  u'joeygraceffa16',
#  u'75',
#  u'bridal',
#  u'lol',
#  u'\U0001f49a',
#  u'on',
#  u'worri',
#  u'thank',
#  u'fun',
#  u'week',
#  u'at',
#  u'send',
#  u'open',
#  u'extens',
#  u'my',
#  u'her',
#  u'\U0001f3dd',
#  u'us',
#  u'new',
#  u'yale',
#  u'effect',
#  u'of',
#  u'are',
#  u'"turn',
#  u'(rememb',
#  u'frank',
#  u'to',
#  u'was',
#  u'member',
#  '<s>',
#  u'star',
#  u'have',
#  u'play',
#  u'you',
#  u'good',
#  u'to',
#  u'my',
#  u'for',
#  u'\u262e',
#  u'fun',
#  u'my',
#  u'on',
#  u'make',
#  u'&amp;',
#  u'a',
#  u'half',
#  u'out',
#  u'bodi',
#  u'domest',
#  u'hs',
#  u'feel',
#  u'to',
#  u'your',
#  u'your',
#  u'particip',
#  '<s>',
#  u'back',
#  '<s>',
#  u'that',
#  '<s>',
#  u'lie',
#  u'usual',
#  u'7:30pm',
#  u"we'r",
#  u'be',
#  u'night',
#  u'rt',
#  u'fgc',
#  u'ps1',
#  u'get',
#  u'of',
#  u'in',
#  u'broccoli',
#  ...]

# %%
pd.DataFrame

# %%
trigram_count = tweets.map(emoji_preprocess).flatMap(trigrams).map(lambda bg: (bg, 1)).reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).collect()

# %%
quadgrams_count = tweets.map(emoji_preprocess).flatMap(quadgrams).map(lambda bg: (bg, 1)).reduceByKey(lambda cnt1, cnt2: cnt1+cnt2).collect()

# %%
bigram_count
# Out:
# [(((u'the',), u'main'), 4),
#  (((u'do',), u'join'), 2),
#  (((u'today',), u'sneak'), 2),
#  (((u'friday',), u'fun'), 12),
#  ((('<s>',), u'out'), 2),
#  (((u'day',), u'the'), 2),
#  (((u'pbs',), u'or'), 2),
#  (((u'releas',), u'it'), 2),
#  ((('<s>',), u'boo'), 2),
#  (((u'\U0001f600',), u'fun'), 2),
#  (((u'excit',), u'highlight'), 2),
#  (((u'two',), u'decad'), 2),
#  (((u'internet',), u'meme'), 2),
#  (((u'accept',), u'alcohol'), 2),
#  (((u'treat',), u'the'), 2),
#  (((u'anoth',), u'weekend'), 2),
#  (((u'should',), u'tri'), 2),
#  (((u'age',), u'4'), 2),
#  (((u'that',), '</s>'), 4),
#  (((u'rav',), u'4'), 2),
#  (((u'hank',), u'to'), 2),
#  (((u'good',), u'hang'), 2),
#  (((u'fun',), u'back'), 2),
#  (((u'fun',), u'regret'), 2),
#  (((u'foam',), u'pit'), 2),
#  (((u'tonight',), u'at'), 4),
#  (((u'fun',), u'click'), 2),
#  (((u'day',), u'with'), 2),
#  (((u'birthday',), u'nicol'), 2),
#  (((u'1',), u'follow'), 2),
#  (((u'fun',), u'bruh'), 2),
#  (((u'now',), u'say'), 2),
#  (((u'knew',), u'they'), 2),
#  (((u'to',), u'let'), 2),
#  (((u'oday',), u'is'), 2),
#  (((u's/o',), u'to'), 2),
#  (((u'grandma',), u'and'), 2),
#  ((('<s>',), u'right'), 2),
#  (((u'fact',), u'dolley'), 2),
#  (((u'\U0001f918',), u'\U0001f3fb'), 12),
#  ((('<s>',), u'een'), 2),
#  (((u'head)@kerrywashington"',), u'*i'), 2),
#  (((u'term',), u'"nerd"'), 2),
#  (((u'paint',), u'and'), 2),
#  (((u'news',), u'you'), 2),
#  (((u'via:',), u'young'), 2),
#  (((u'be',), u'stream'), 2),
#  (((u'young',), '</s>'), 2),
#  (((u'they',), u'give'), 2),
#  (((u'your',), u'question'), 2),
#  (((u'fun',), u'\U0001f64c'), 2),
#  (((u'fun',), u'memori'), 4),
#  (((u'and',), u'powerf'), 2),
#  (((u'get',), u'them'), 2),
#  (((u'pleaser',), u'i'), 2),
#  (((u'play',), u'in'), 2),
#  (((u'fun',), u'sexi'), 2),
#  (((u'my',), u'grandma'), 4),
#  (((u'and\u2026',), '</s>'), 4),
#  (((u"couldn't",), u'get'), 2),
#  (((u'&amp;',), u'respect'), 2),
#  (((u'deni',), u':)'), 2),
#  (((u'hey',), u'have'), 2),
#  ((('<s>',), u'his'), 22),
#  (((u'so',), u'fa'), 2),
#  (((u'saddest',), u'landscap'), 2),
#  ((('<s>',), u'summer'), 2),
#  (((u'help',), u'fin'), 2),
#  (((u'fun',), u':)'), 10),
#  (((u'need',), u'peopl'), 2),
#  (((u'sad',), u'reminisc'), 2),
#  (((u'are',), u'smoke'), 2),
#  (((u'way',), u'to'), 4),
#  (((u'msg-2',), u'the'), 2),
#  (((u'how',), u'fun'), 6),
#  (((u'are',), u'and'), 2),
#  (((u'\U0001f600',), '</s>'), 6),
#  (((u'barf',), u'into'), 2),
#  (((u'me',), u'treat'), 2),
#  (((u'conserv',), u'today'), 2),
#  (((u'staff',), u'and'), 2),
#  (((u"doesn't",), u'answer'), 2),
#  (((u'have',), u'depress'), 2),
#  (((u'actor',), u'walk'), 2),
#  (((u'than',), u'school'), 2),
#  (((u'wait',), u'for'), 10),
#  ((('<s>',), u'kati'), 2),
#  (((u'o',), u'much'), 2),
#  (((u'endless',), u'fun'), 2),
#  (((u'hey',), u'a'), 2),
#  (((u'skype',), u'my'), 2),
#  ((('<s>',), u'zootopia'), 4),
#  (((u'studio',), u'whos'), 2),
#  (((u"we'r",), u'just'), 2),
#  (((u'great',), u'detect'), 2),
#  (((u'sh*t',), '</s>'), 2),
#  ((('<s>',), u'new'), 2),
#  (((u'problem',), u'no'), 2),
#  (((u'fun',), u'sweati'), 2),
#  (((u'and',), u'inform'), 2),
#  (((u'day',), u'we'), 4),
#  (((u'3-gun',), u'match'), 2),
#  (((u'realli',), u'enjoy'), 2),
#  (((u'his',), u'is'), 6),
#  (((u'onli',), u'one'), 6),
#  (((u"i'm",), u'still'), 2),
#  (((u'quiz',), u'-'), 4),
#  (((u'career',), u'\U0001f44c'), 2),
#  (((u'of',), u'-'), 2),
#  (((u'fun',), u'horsie~'), 2),
#  (((u'can',), u'have'), 4),
#  (((u'\U0001f438',), u'\u2615'), 30),
#  (((u'you',), u'think'), 2),
#  (((u'loui',), u'is'), 2),
#  (((u'insan',), u'sens'), 2),
#  ((('<s>',), u'dololo'), 2),
#  (((u'processabow',), u'everyth'), 2),
#  (((u'on',), u'game'), 2),
#  (((u'place',), u'of'), 4),
#  ((('<s>',), u'check'), 6),
#  (((u'stencil',), u'add'), 2),
#  (((u"i'll",), u'be'), 2),
#  (((u'shot',), u'updat'), 2),
#  ((('<s>',), u'at'), 2),
#  (((u'patron',), u'of'), 2),
#  (((u'peopl',), u'is'), 2),
#  (((u'my',), u'person'), 2),
#  (((u'your',), u'area:'), 2),
#  (((u'but',), u'like'), 2),
#  (((u'this',), u'now'), 2),
#  (((u'cudd',), u'mascot'), 2),
#  (((u'game',), u'giveaway'), 2),
#  (((u'seem',), u'there'), 2),
#  (((u'you',), u'charlott'), 2),
#  (((u'violenc',), u'and'), 2),
#  (((u'to',), u'beauti'), 2),
#  (((u'brave',), u'the'), 2),
#  (((u'touch',), u'story\u2026'), 2),
#  ((('<s>',), u'yeah'), 6),
#  (((u'have',), u'maaaaad'), 2),
#  (((u'i',), u'swear'), 2),
#  (((u'a',), u'amaz'), 12),
#  (((u'about',), u'expression"'), 2),
#  (((u'\U0001f602',), u'\U0001f60f'), 2),
#  (((u'the',), u'1000s'), 2),
#  (((u'poker',), u'look'), 2),
#  (((u'of',), u'game'), 2),
#  (((u'boy',), u'and'), 2),
#  ((('<s>',), u's&amp;d'), 2),
#  (((u'x',), '</s>'), 8),
#  (((u'of',), u'the'), 30),
#  (((u'have',), u'mad'), 2),
#  (((u'"when',), u'my'), 2),
#  (((u'by',), u'delia'), 2),
#  (((u'tour',), u':/'), 2),
#  (((u'&amp;',), u'then'), 2),
#  (((u'amazon',), u'enter'), 2),
#  (((u'this',), u'pictur'), 2),
#  (((u'with',), u'drunk'), 4),
#  (((u'having~"',), '</s>'), 2),
#  (((u'fun',), u'one'), 4),
#  (((u'realli',), u'anderp'), 2),
#  (((u'ruffl',), u'via'), 2),
#  (((u'his',), u'mom'), 2),
#  (((u'boy',), u'enjoy'), 2),
#  (((u'thank',), u'for'), 16),
#  (((u'street',), u'paid'), 2),
#  (((u'4)',), u'badg'), 2),
#  (((u'part',), u'for'), 2),
#  (((u'\U0001f3fe',), u'\U0001f62d'), 2),
#  (((u'out',), u'these'), 4),
#  (((u'for',), u'at'), 2),
#  ((('<s>',), u'get'), 12),
#  (((u'game',), u'thank'), 6),
#  (((u'his',), u'seem'), 2),
#  (((u'attent',), u':'), 2),
#  (((u'was',), u'that'), 2),
#  (((u'happi',), '</s>'), 2),
#  (((u'phone',), u'and'), 2),
#  (((u'but',), u'baestro'), 2),
#  (((u'in',), u'may'), 2),
#  (((u'member',), u'it'), 2),
#  (((u'bag',), u'was'), 2),
#  (((u'parkour',), u'&amp;'), 2),
#  ((('<s>',), u'cuti'), 2),
#  ((('<s>',), u'move'), 2),
#  (((u'newspap',), u'zaman'), 2),
#  (((u'citi',), u'fun'), 2),
#  (((u'with',), u'duke'), 2),
#  ((('<s>',), u'\u2190'), 2),
#  (((u'at',), u'pittsburgh'), 2),
#  (((u'~tackl',), '</s>'), 2),
#  (((u'have',), u'unlimit'), 2),
#  (((u'girl',), u'like'), 6),
#  (((u'would',), u'remak'), 2),
#  (((u'brows',), u'our'), 2),
#  (((u'pleas',), u'in'), 2),
#  (((u'tri',), u'to'), 4),
#  (((u'that',), u'make'), 4),
#  (((u'beast',), u'mode'), 2),
#  ((('<s>',), u'show'), 2),
#  (((u'in',), u'a'), 12),
#  (((u'leadership',), u'develop'), 2),
#  (((u'10x',), u'brighter'), 2),
#  (((u'such',), u'a'), 26),
#  (((u'ek\u2026',), '</s>'), 2),
#  ((('<s>',), u'are'), 2),
#  (((u'low',), u'limit'), 2),
#  (((u'\u266a',), '</s>'), 2),
#  ((('<s>',), u'find'), 6),
#  (((u'8/7c',), '</s>'), 2),
#  (((u'eye',), u'infect'), 2),
#  (((u'dog',), u'friend'), 2),
#  (((u'everi',), u'time'), 2),
#  (((u'than',), u'senior'), 2),
#  ((('<s>',), u'2nd'), 4),
#  (((u'good',), u'job'), 2),
#  (((u'fun',), u'via'), 4),
#  (((u'my',), u'kit'), 2),
#  (((u'it',), u'been'), 12),
#  (((u'heh',), u'no'), 2),
#  (((u'play',), u'tell'), 2),
#  (((u'facts:',), u'onli'), 2),
#  (((u'and',), u'sip'), 2),
#  (((u'\U0001f607',), u'set'), 2),
#  (((u'im',), u'skype'), 2),
#  (((u'love',), u'quarter'), 2),
#  (((u'the',), u'anim'), 2),
#  (((u'he',), u'is'), 8),
#  (((u'littl',), u'kid'), 2),
#  (((u'out',), u'lane'), 2),
#  (((u'and',), u'heart'), 2),
#  (((u'allow',), u'2'), 2),
#  (((u'kilig',), u'fun'), 2),
#  (((u'night',), u'w/'), 2),
#  (((u'commit',), u'will'), 2),
#  (((u'day',), u'and'), 2),
#  (((u'ot9',), u'for'), 2),
#  (((u'giveaway',), u'1'), 2),
#  (((u'\U0001f643',), u'nike'), 2),
#  ((('<s>',), u'our'), 4),
#  (((u'game',), u'to'), 6),
#  (((u'at',), u'least'), 4),
#  (((u'pregam',), u'rollercoast'), 2),
#  (((u'fun',), u'though'), 2),
#  (((u'would',), u'be'), 6),
#  (((u'mission',), u'and'), 2),
#  (((u'magic',), u'know'), 2),
#  (((u'connect',), u'fit'), 2),
#  ((('<s>',), u'everyon'), 4),
#  (((u'us',), u'on'), 2),
#  (((u'guess',), u'who'), 14),
#  (((u'*make',), u'a'), 2),
#  ((('<s>',), u'"wouldn\'t'), 2),
#  (((u'at',), u'ryan'), 2),
#  (((u'my',), u'wife(in'), 2),
#  (((u'okkinderhook',), u'(@okkinderhook):'), 2),
#  (((u'braver',), u'fiercer'), 2),
#  (((u'the',), u'darl'), 2),
#  ((('<s>',), u'bloodi'), 2),
#  (((u'soooo',), u'much'), 6),
#  (((u'fun',), u'art"'), 2),
#  (((u'rather',), u'than'), 2),
#  (((u'joke',), u'about'), 2),
#  (((u'me',), u'win'), 2),
#  (((u'the',), u'big'), 2),
#  (((u"i'm",), u'home'), 2),
#  (((u'guess',), u'be'), 2),
#  (((u'day',), u'wtf'), 2),
#  (((u'that',), u'and'), 2),
#  (((u'and',), u'like'), 2),
#  (((u'agre',), '</s>'), 2),
#  (((u'happi',), u'weekend'), 4),
#  (((u'second',), u'to'), 2),
#  (((u'to',), u'end'), 4),
#  (((u'w/',), u'recent'), 4),
#  (((u'that',), u'was'), 36),
#  (((u'the',), u'cast'), 2),
#  (((u'out',), u'with'), 12),
#  (((u'rippen',), u'on'), 2),
#  (((u'gonna',), u'be'), 16),
#  (((u'fit',), u'(shutdown'), 2),
#  (((u'is',), u'cram'), 2),
#  (((u'\U0001f3b6',), '</s>'), 2),
#  (((u'my',), u'work'), 2),
#  (((u'grace',), u'lot'), 2),
#  (((u'infect',), u'bad'), 2),
#  (((u'still',), u"can't"), 2),
#  (((u'lit',), u'asf'), 2),
#  (((u"i'm",), u'in'), 2),
#  (((u'after',), u'scho\u2026'), 2),
#  ((('<s>',), u'\U0001f602'), 2),
#  (((u'4',), u'u'), 2),
#  (((u'much',), u'about'), 2),
#  (((u'fun',), u'loui'), 2),
#  (((u'like',), '</s>'), 6),
#  (((u'cam',), u'now'), 2),
#  (((u'us/can/uk)',), '</s>'), 2),
#  (((u'name',), u'firstborn'), 2),
#  (((u'rt',), u'got'), 2),
#  (((u'fgc',), u'top'), 4),
#  (((u'ps1',), u'pad'), 2),
#  (((u'get',), u'paid'), 2),
#  (((u'of',), u'love'), 2),
#  (((u'in',), u'me'), 2),
#  (((u'broccoli',), '</s>'), 8),
#  ...]

# %%
bigram_dict = defaultdict(Counter)
trigram_dict = defaultdict(Counter)
quadgram_dict= defaultdict(Counter)

# %%
for (((w0,),w1) , cnt) in bigram_count:
    bigram_dict[w0][w1] = cnt

# %%
for (((w0, w1), w2), cnt) in trigram_count:
    trigram_dict[(w0, w1)][w2] = cnt

# %%
for (((w0, w1, w2), w3), cnt) in quadgrams_count:
    quadgram_dict[(w0, w1, w2)][w3] = cnt

# %%
sum(bigram_dict['the'].values())
# Out:
# 550

# %%
for key in bigram_dict:
    total = sum(bigram_dict[key].values())
    for val in bigram_dict[key]:
        bigram_dict[key][val] = bigram_dict[key][val]/float(total)

# %%
for key in trigram_dict:
    total = sum(trigram_dict[key].values())
    for val in trigram_dict[key]:
        trigram_dict[key][val] = trigram_dict[key][val]/float(total)

# %%
for key in quadgram_dict:
    print key
    total = sum(quadgram_dict[key].values())
    for val in quadgram_dict[key]:
        quadgram_dict[key][val] = quadgram_dict[key][val]/float(total)
# Out:
# (u'all', u'treat', u'the')
# (u'it', u'so', u'silli')
# (u'the', u'day', u'begin')
# (u'make', u'life', u'fun')
# (u've', u'to', u'loka')
# (u'short:', u'i', u'sold')
# (u'clear', u'all', u'my')
# (u'eye', u'infect', u'bad')
# (u'world', u'of', u'pinot')
# (u'project', u'for', u'the')
# (u'asian', u'everywher', u'in')
# (u'of', u'you', u'even')
# (u'friday', u'we', u'have')
# (u'fun', u'onli', u'3')
# (u'you', u'might', u'be')
# (u'healthi', u'day', u'of')
# (u'karaok', u'in', u'japan')
# (u'get', u'the', u'new')
# (u'an', u'evil', u'moodi')
# (u'your', u'couch', u'it')
# (u'enjoy', u'the', u'hap')
# (u'bag', u'was', u'soak')
# (u'a', u'name', u'brand')
# ('<s>', u'"make', u'it')
# ('<s>', u'internet:', u'*make')
# (u'fact', u'cenk', u'uygur')
# (u'blue', u'to', u'you')
# (u'have', u'the', u'energi')
# (u'about', u'her', u'new')
# (u'guy', u'\U0001f618', u'thank')
# (u'\U0001f3b6', u'\u2764', u'\ufe0f')
# (u'for', u'fun', u'again')
# (u'next', u'to', u'my')
# (u'annoy', u'voic', u'do')
# (u'review:', u'(now', u'play')
# (u'the', u'state', u'championship')
# (u'breath', u'again', u'record')
# (u'yale', u'pitcher', u'was')
# (u'the', u'women', u'team')
# (u'that', u'one', u'girl')
# (u'it', u'air', u'brilliant')
# (u"they'r", u'about', u'htt\u2026')
# (u'ctmc', u'is', u'still')
# (u'page', u'look', u'forward')
# (u'milf', u'for', u'adult')
# (u'fun', u'today', u'\U0001f918')
# (u'emte', u'dololo', u'nasti')
# (u'to', u'rememb', u'those')
# (u'will', u'be', u'fun')
# (u'i', u'notic', u'my')
# (u'fun-at', u'least', u'he')
# (u'and', u'adopt', u'everi')
# (u'paid', u'tribut', u'to')
# (u'eyebag', u'more', u'fun')
# (u'they', u'could', u'be')
# (u'good', u'screenplay', u'by')
# (u"don't", u'wear', u'leg')
# (u'good', u'movi', u'has')
# (u'fun', u'dure', u'the')
# (u'set', u'hope', u'this')
# (u'my', u'bodi', u'doe')
# (u'friend', u'today', u'and')
# (u'simpl', u'social', u'tactic')
# (u'at', u'6:30pm', u'with')
# (u'is', u'fun', u'as')
# (u'all', u'for', u'make')
# (u'michaelbr4dley', u'and', u'boy')
# (u'do', u'what', u'you')
# (u'sit', u'next', u'to')
# (u'rearrang', u'the', u'kitchen')
# (u'with', u'you', u'enjoy')
# (u'me-', u'i', u'hate')
# (u'the', u'ticket', u'booth')
# ('<s>', u'bore', u'lone')
# (u'tabl', u'game', u'to')
# (u'by', u'all', u'at')
# (u'time', u'fli', u'when')
# ('<s>', u'film', u'someth')
# ('<s>', u'i', u'cannot')
# (u'i', u"can't", u'lie')
# ('<s>', u'guy', u'make')
# (u'fun', u'to', u'be')
# (u'to', u'find', u'ou')
# (u'still', u'in', u'after')
# (u'one', u'with', u'a')
# (u'6', u'holiday', u'to')
# (u'school', u'holiday', u'again')
# (u"can't", u'wait', u'for')
# (u'peel', u'is', u'half')
# (u'was', u'a', u'lot')
# (u'be', u'a', u'awesom')
# (u'seuss', u'birthday', u'make')
# (u'futur', u'is', u'10x')
# ('<s>', u'smfh', u'rt')
# (u'i', u'need', u'anoth')
# (u'knew', u'they', u'could')
# (u'with', u'the', u'saddest')
# (u'rate', u'\U0001f446', u'\u2757')
# ('<s>', u'i', u'work')
# (u'submit', u'photo', u'onlin')
# (u'night', u'and', u'with')
# (u'to', u'thank', u'you')
# (u'loud', u'af', u'bc')
# (u"i'm", u'gonna', u'miss')
# (u'to', u'revisit', u'the')
# (u'fast-pac', u'i', u"can't")
# (u'damn', u'was', u'a')
# (u'100mph', u'we', u'drif')
# (u'fun', u'chat', u'w/')
# (u"don't", u'make', u'this')
# (u"you'r", u'send', u'me')
# (u'rt', u'&amp;', u'show')
# (u'my', u'bag', u'was')
# (u'fun', u'fact:', u'sonia')
# (u'to', u'see', u'them')
# (u'*physic', u'scale*', u"i'v")
# (u'someon', u'like', u'a')
# (u'skin', u'tone', u'they')
# (u'bad', u'back', u'pain')
# ('<s>', u'happi', u'friday')
# (u'in', u'to', u'hot')
# (u'friday', u'fun', u'time')
# (u'fun', u'rainbow', u'flat')
# (u'new', u'peopl', u'nearbi')
# (u'sa', u'kilig', u'fun')
# (u'go', u'knight', u'go')
# (u'\U0001f595', u'\U0001f3ff', u'\U0001f602')
# (u'lie', u'haha', u'but')
# ('<s>', u'go', u'to')
# (u'the', u'pit', u'proud')
# (u"i'll", u'be', u'on')
# (u'that', u"must'v", u'been')
# (u'get', u'40000', u'subscrib')
# (u'between', u'the', u'redwood')
# (u'place', u'at', u'the')
# (u'a', u'fun-fil', u'night')
# (u'be', u'my', u'person')
# (u'had', u'soooo', u'much')
# (u'often', u'probabl', u'after')
# (u'step', u'on', u'your')
# (u'"wouldn\'t', u'it', u'be')
# (u'good', u'mom', u'will')
# (u'\U0001f61e', u'\U0001f601', u'\U0001f600')
# (u'day', u'at', u'work')
# (u'and', u'sip', u'class')
# (u'fun', u'to', u'find')
# (u'face', u'of', u'fun')
# (u'now', u'my', u'hockey')
# (u'guy', u'make', u'this')
# (u'will', u'you', u'get')
# (u'aye', u'have', u'fun')
# (u'like', u'sex', u'with')
# (u'for', u'the', u'fine')
# (u'back', u'for', u'more')
# (u'fun', u'time', u'at')
# (u'today', u'w/@gwynethpaltrow', u'learn')
# (u'awesom', u'cut', u'by')
# (u'an', u'effect', u'mastermind')
# (u'fun', u'on', u'stage')
# (u'onc', u'a', u'year')
# (u'yo', u'yo', u'yo')
# (u'alway', u'a', u'fun')
# ('<s>', u'friend', u'grab')
# (u'a', u'good', u'job')
# (u'in', u'should', u'be')
# (u'ocelot', u'do', u'for')
# (u'play', u'"kar-mi"', u'it')
# (u'fun', u'boo', u'be')
# (u'plan', u'4', u'u')
# (u'with', u'your', u'-')
# (u'pictur', u'day', u'at')
# (u'and', u'head', u'to')
# (u'way', u'unless', u'just')
# (u'some', u'fun', u'last')
# (u'w/', u'flannel', u'back')
# (u'hope', u"y'all", u'enjoy')
# ('<s>', u'kati', u'hopkin')
# (u'first', u'of', u'all')
# (u'bridesmaid', u"it'll", u'be')
# (u'never', u'get', u'those')
# (u'such', u'a', u'sweet')
# (u'convinc', u'peopl', u'not')
# (u'keep', u'on', u'do')
# (u'it', u'not', u'the')
# (u'glossi', u'new', u'one')
# (u'much', u'fun', u'i')
# (u'the', u'band', u'from')
# ('<s>', u'hank', u'for')
# (u'they', u'have', u'less')
# (u'ago', u'but', u"couldn't")
# (u'music', u'to', u'kick')
# (u'and', u'cruel', u'it')
# (u'new', u'but', u'also')
# (u'as', u'she', u'love')
# (u'i', u'find', u'hilari')
# (u'rt', u'for', u'a')
# (u'all', u'your', u'stori')
# (u'to', u'see', u'more')
# (u'a', u'lion', u'in')
# (u'more', u'save', u'grace')
# (u'new', u'kinki', u'fun')
# (u'especi', u'at', u'night')
# (u'10pm', u'join', u'in')
# (u'you', u'be', u'get')
# (u'all', u'have', u'maaaaad')
# ('<s>', u"i'm", u'not')
# (u'-', u'clean', u'up')
# (u'it', u'got', u'excel')
# (u'play', u'tell', u'us')
# ('<s>', u'there', u'are')
# (u'pleas', u'eat', u'two')
# (u'hey', u'have', u'fun')
# (u'bring', u'that', u'littl')
# (u'fun', u'sexi', u'social')
# (u'as', u'you', u'are')
# (u'this', u'it', u'so')
# (u'and', u'keep', u'your')
# (u'discuss', u'that', u'will')
# (u'my', u'parent', u'the')
# (u'she', u'throw', u'a')
# (u'price', u'rang', u'from\u2026')
# (u'12-inch', u'star', u'prima')
# (u'after', u'my', u'midterm')
# (u'andrew', u'and', u'alex')
# (u'the', u'rain', u'was')
# (u'a', u'fun', u'call')
# (u'was', u'hack', u'back')
# (u'chines', u'in', u'order')
# (u'have', u'"so', u'much')
# (u'fun', u'night', u'w/')
# (u'all', u'involv', u'with')
# (u'you', u'guy', u'do')
# (u'top', u'leopard', u'green')
# (u'color', u'select', u'|')
# (u'today', u'was', u'so')
# (u'the', u'snow', u'&amp;')
# (u'husker', u'and', u'everyon')
# ('<s>', u'\U0001f602', u'\U0001f602')
# (u'play', u'for', u'fun')
# (u'friday', u'fun', u'and')
# (u'heaven', u'basketbal', u'court')
# (u'audible/amazon/itun', u'adventur', u'with')
# (u'to', u'live', u'there"')
# (u'when', u"you'r", u'bore')
# (u'of', u'your', u'water')
# (u'a', u'student', u'15')
# (u'find', u'out', u'how')
# (u'of', u'power', u'such')
# (u'kill', u'(endangered)', u'anim')
# (u'(level', u'4)', u'badg')
# (u'take', u'lot', u'of')
# (u"i'd", u'just', u'like')
# (u'\U0001f4f7', u'wtf-fun-factss:', u'clear')
# (u'for', u'earli', u'bday')
# (u'sneez', u'or', u'cough')
# (u'and', u'i', u'can')
# (u'with', u'this', u'special')
# (u'w/', u'recent', u'thank')
# (u'friday', u'night', u'is')
# ('<s>', u'it', u'feel')
# (u'exhibit', u'at', u'cotteslo')
# (u'it', u'simpl', u'make')
# (u'thoughth', u'journey', u'was')
# (u'impress', u'by', u'women')
# (u'we', u'still', u"can't")
# (u'time', u'the', u'fun"')
# (u'just', u'fun', u'to')
# (u'fun', u'and', u'eat')
# ('<s>', u'honcho', u'gang')
# (u'his', u'daughter', u'is')
# (u'i', u'rememb', u'that')
# ('<s>', u'it', u'fun')
# (u'color', u'sheet', u'for')
# (u'will', u'be', u'broke')
# ('<s>', u'right', u'but')
# (u'up', u'earli', u'tomorrow')
# (u'news', u'inde', u'should')
# (u'stress', u'love', u'life')
# (u'number', u'of', u'lacklust')
# (u'ocelot', u'now', u'get')
# (u'is', u'here:', u'morph')
# (u'refresh', u'my', u'mind')
# (u'tube', u'top', u'leopard')
# (u'and', u'have', u'hella')
# (u'go', u'100mph', u'we')
# (u'do', u'anyth', u'fun')
# (u'vote', u'for', u'him')
# (u'n', u'he', u'is')
# (u'like', u'leia', u'and')
# (u'fun', u'with', u'\u2764')
# (u'june', u'17', u'&amp;')
# (u'where', u'i', u'live')
# (u'and', u'project', u'a')
# (u'unless', u'i', u'feel')
# ('<s>', u'if', u"you'r")
# (u'the', u'best', u'dress')
# (u'or', u'taco', u'\U0001f355')
# (u'fun', u'on', u'a')
# ('<s>', u'bless', u'you')
# (u'inquisit', u'okay', u'that')
# (u'fun', u'and', u'project')
# (u'of', u'my', u'friend')
# (u'oh', u'the', u'fun')
# ('<s>', u'i', u'just')
# (u'random', u'pic', u'so')
# (u'women', u'boot', u'camp')
# (u'7:30pm', u'and', u'get')
# (u'dalek', u'&amp;', u'oh')
# ('<s>', u'would', u'have')
# (u'912', u'from', u'10pm')
# (u'lookin', u'like', u"they'r")
# (u'all', u'at', u'the')
# ('<s>', u'and', u'fun')
# (u'this', u'was', u'fun')
# (u'stop', u'in', u'and')
# (u'girl', u'come', u'outta')
# (u'the', u'girl', u'who')
# (u'and', u'horni', u'\U0001f4a6')
# (u'"liked"', u'us', u'on')
# (u'fun', u'-', u'bts')
# (u'them', u'but', u'it')
# (u'foam', u'pit', u'then')
# (u'last', u'night', u"we'r")
# (u"you'r", u'no', u'fun')
# (u'a', u'lot', u'of')
# (u'shit', u'can', u'easili')
# (u'fun', u'q&amp;a', u'with')
# ('<s>', u'you', u'kid')
# (u'a', u'game', u'let')
# (u'epcot', u'in', u'walt')
# (u'tour', u':/', u'but')
# (u"you'r", u'way', u'more')
# (u'photo', u'onlin', u'get')
# (u'actual', u'had', u'fun')
# (u'same', u'on', u'as')
# (u'do', u'what', u'they')
# (u'of', u'the', u'class')
# (u'video', u'make', u'fun')
# (u'who', u'is', u'a')
# (u'fun', u'game', u'veri')
# (u'so', u'fun', u'now')
# (u'birthday', u'pretti', u'i')
# (u'tower', u'are', u'fun')
# (u'forward', u'to', u'it')
# (u'omorrow', u'bout', u'to')
# (u'me', u'str8', u'yass')
# (u'beast', u'mode', u'sa')
# ('<s>', u'fun', u'easter')
# (u'place', u'today', u'with')
# (u'superbowl', u'backstag', u'pic')
# (u'readi', u'for', u'the')
# ('<s>', u'back', u'on')
# (u'book', u'to', u'write')
# (u'victoria', u'univers', u'of')
# (u'with', u'you', u'that')
# (u'mind', u'clear', u'all')
# ('<s>', u'awh', u'i')
# (u'a', u'perfect', u'fit')
# (u'learn', u'their', u'power')
# (u'for', u'us', u'to')
# ('<s>', u'fun', u'shoot')
# (u'seem', u'there', u'a')
# (u'(5-3', u'to', u'td)')
# (u'much', u'i', u"can't")
# (u'funstay', u'trueb', u'real')
# (u'the', u'tl', u'and')
# (u'but', u'night', u'are')
# (u'have', u'some', u'fun')
# (u'bore', u'but', u'night')
# (u'io', u'whi', u'not')
# (u'dead', u'inquisit', u'okay')
# (u'much', u'fun', u'roseburg')
# (u'a', u'awesom', u'nigh')
# (u'with', u'you', u'sinc')
# (u'after', u'uptown', u'status')
# (u'what', u'you', u'love')
# (u'my', u'wrestlemania', u'bing')
# (u'i', u'say', u'get')
# (u'fun', u'&amp;', u'game')
# (u'you', u'stay', u'home')
# (u'then', u'how', u'i')
# (u'zootopia', u'to', u'a')
# (u'for', u'the', u'all')
# ('<s>', u'i', u'post')
# (u'facebook', u'page', u'come')
# (u'much', u'fun', u'via')
# (u'and', u'quest;', u'have')
# (u'fun', u'love', u'motiv')
# (u'see', u'our', u'full')
# (u'as', u'an', u'excus')
# (u'job', u'well', u'done')
# (u'close', u'last', u'game')
# (u'pitcher', u'was', u'homecom')
# (u'tri', u'to', u'play')
# ('<s>', u'awesom', u'you')
# (u'hey', u"we'r", u'at')
# (u'last', u'weekend', u'staycat')
# (u'prevent', u'you', u'from')
# (u'fun', u'at', u'first')
# (u'myselflisten', u"we'll", u'talk')
# (u'royal', u'and', u'other')
# ('<s>', u'boyz', u'with')
# (u'longer', u'talk', u'everyth')
# (u'he', u'was', u'make')
# (u'insid', u'hahahahaha', u'\U0001f606')
# (u'math', u'fun', u'via')
# (u'phone', u'and', u'start')
# (u'out', u'of', u'8')
# (u'so', u'much', u'for')
# (u'be', u'such', u'a')
# (u'hope', u"you'r", u'have')
# (u'addict', u'strategi', u'game')
# (u'than', u"i'm", u'suppos')
# (u'into', u'a', u'food')
# (u'this', u'look', u'fun')
# (u'is', u'today', u'come')
# (u'especi', u'when', u'pudg')
# (u'steam', u'game', u'giveaway')
# (u'how', u'at', u'bella')
# (u'and', u'be', u'reward')
# (u'hankssssssssss', u'u', u'too')
# (u'fun', u'while', u'rais')
# (u'fun', u'not', u'onli')
# (u'cool', u'action', u'and')
# (u'3', u'time', u'and')
# (u'the', u'1st', u'just')
# (u'are', u'fun', u'\U0001f35f')
# (u'se', u'louisiana', u'2-1')
# (u'same', u'time', u'kindi')
# (u'mag', u'send', u'rin\u2026')
# (u'today', u'at', u"i'll")
# (u"can't", u'wait', u'to')
# (u'is', u'a', u'chanc')
# (u'clash', u'royal', u'and')
# (u'box', u'full', u'of')
# ('<s>', u'here', u'are')
# (u'gang', u'\U0001f525', u'\U0001f608')
# (u'import', u'one', u'day')
# (u'on', u'cpyne', u'face')
# (u'fun', u'friend', u'got')
# (u'have', u'arriv', u'let')
# (u'were', u'lit', u'asf')
# (u'of', u'fun', u'or')
# (u'out', u'by', u'myself')
# (u'get', u'out', u'by')
# ('<s>', u"they'r", u'so')
# (u'amazon', u'enter', u'to')
# (u'global', u'warm', u'was')
# (u'\u201c@mialee1976:', u'omgal', u'i')
# (u'use', u'to', u'love')
# (u'better', u'be', u'less')
# ('<s>', u'it', u'alway')
# (u'for', u'your', u'all')
# (u'a', u'dark', u'skin')
# (u'again', u'that', u'was')
# (u'just', u'gonna', u'have')
# (u'suka', u'kau', u'thing')
# (u'at', u'children', u'day:')
# (u'for', u'the', u'day')
# (u'chang', u'night', u'light')
# (u'come', u'to', u'watch')
# (u'definit', u'share', u'the')
# (u'yesterday', u'color', u'parti')
# (u'ani', u'fun', u'friday')
# (u'jus', u'for', u'fun')
# (u'again', u'such', u'fun')
# (u'practic', u'in', u'the')
# (u'realli', u'anderp', u'have')
# (u'in', u'but', u'enjoy')
# (u'snapchat', u'of', u'the')
# (u'liptifulintern', u'in', u'today')
# (u'goody/fy', u'et/c', u'and')
# (u'ppl', u'need', u'to')
# (u'do', u'they', u'give')
# (u'hilari', u'internet', u'meme')
# (u'fun', u'at', u'chaz')
# (u'11pm', u'join', u'me')
# (u'tail', u'wag', u'\U0001f43e')
# (u'with', u'the', u'squad')
# (u'to', u'choos', u'a')
# (u'damn', u'cowork', u'here')
# (u'cours', u'such', u'a')
# (u'to', u'actual', u'enjoy')
# ('<s>', u'bsnyc', u'friday')
# (u'ignor', u'racist', u'classist')
# (u'rampant', u'at', u'what')
# (u'rise', u'to', u'beauti')
# (u'join', u'in', u'for')
# (u'activ', u'from', u'disney')
# (u'like', u'22', u'request')
# (u'to', u'do', u'someth')
# (u'releas', u'vinyl', u'too')
# (u'alotta', u'movi', u'huzband')
# (u'bobbi', u'bday', u'bash')
# (u'cave', u'in', u'and')
# (u'up', u'to', u'$20')
# ('<s>', u'fun', u'with')
# (u'us', u'your', u'favorit')
# (u'for', u'at', u'least')
# (u'limit', u'explor', u'combat')
# (u'wwhooooaaaaaa', u'gooood', u'luck')
# (u'but', u'like', u'she')
# (u'bit', u'and', u'fun')
# ('<s>', u'but', u'it')
# ('<s>', u'fun', u'friday')
# (u'me', u'right', u'now')
# (u'amaz', u'weekend', u'a')
# (u'well', u'it', u'just')
# (u'for', u'alway', u'captur')
# (u';)', u'have', u'fun')
# ('<s>', u'true', u'lol')
# (u'are', u'up', u'at')
# (u'good', u'game', u'to')
# (u'today', u'was', u'such')
# (u'check', u'out', u'lane')
# ('<s>', u'my', u'of')
# (u'or', u'spinkour', u'for')
# (u'he', u'is', u'a')
# (u'crochet', u'in', u'makerspac')
# (u'am', u'hope', u'it')
# (u'about', u'expression"', u'show')
# (u'singl', u'so', u'damn')
# (u'fun', u'today', u'\U0001f60a')
# (u'lion', u'for', u'kid')
# (u'kati', u'seven', u'lake')
# (u'just', u'to', u'say')
# (u'to', u'hangout', u'with')
# (u'wanna', u'have', u'some')
# (u'ego', u'that', u'be')
# (u'pit', u'then', u'realiz')
# (u'a', u'kid', u'a')
# ('<s>', u'he', u'is')
# (u'hour', u'tomorrow', u'yet')
# (u'dog', u'bone', u'necklac')
# (u'fun', u'&amp;', u'be')
# (u'a', u'rare', u'onc')
# (u'the', u'best', u'joke')
# (u'difficult', u'time', u'and')
# (u'with', u'friend', u'are')
# (u'audienc', u'breath', u'again')
# (u'\U0001f607', u'set', u'me')
# (u'whi', u'is', u'it')
# (u'weather', u'is', u'not')
# (u"n'", u'my', u'mini')
# (u'haha', u'it', u"wasn't")
# (u'show', u'up', u'and')
# (u'one', u'day', u"we'r")
# (u'a', u'helluva', u'lot')
# (u'your', u'thought', u'after')
# (u'folk', u'hop', u'sound')
# (u'q&amp;a', u'with', u'duke')
# (u'with', u'fun', u'-')
# (u'hockey', u'is', u'so')
# (u'out', u'but', u'then')
# ('<s>', u"i'm", u'particip')
# (u'orang', u'has', u'a')
# (u'the', u'world', u'of')
# (u'time', u'in', u'orlando')
# (u'take', u'a', u'deep')
# (u'play', u'and', u'have')
# ('<s>', u'zootopia', u'has')
# (u'26)', u'yep', u'dole')
# (u'yall', u'addict', u'to')
# (u'huhuhu', u'have', u'fun')
# (u'this', u'week', u'\U0001f3dd')
# (u'repli', u'to', u'me')
# ('<s>', u'well', u'done')
# (u'up', u'for', u'some')
# (u'(@okkinderhook):', u'super', u'slide')
# (u'*make', u'fun', u'of')
# (u'lambhel', u'i', u"don't")
# (u'a', u'margarita', u'and')
# ('<s>', u'shop', u'for')
# (u'it', u'fun', u'at')
# (u'and', u'you', u'stay')
# (u'fun', u'and', u'danc')
# (u'on', u'join', u'me')
# (u'ecu', u'walk', u'walk')
# (u'i', u'post', u'15')
# (u'come', u'to', u'our')
# (u'life', u'that', u'make')
# (u'those', u'tail', u'wag')
# (u'care', u'and', u'tell')
# (u'corner', u'store', u'and')
# (u'naughti', u'fun', u'xxx')
# (u'have', u'fun', u'boo')
# (u'the', u'skin', u'tone')
# (u'so', u'freak', u'yummi')
# (u'school', u'right', u'here')
# (u'was', u'to', u'make')
# (u'2', u'prinsen', u'prinsenstraat\u2026')
# (u'\U0001f601', u'mag', u'send')
# (u'with', u'today', u'\U0001f60d')
# (u'say', u'anyth', u'other')
# (u'18', u'becaus', u'i')
# (u'or', u'whatev', u'you')
# (u'this', u'shit', u'for')
# (u'a', u'big', u'group')
# (u'girl', u'weekend', u'we')
# (u'know', u'that', u'have')
# (u'my', u'mom', u'got')
# (u'freak', u'yummi', u'\U0001f60d')
# (u'would', u'end', u'up')
# (u'of', u'all', u"i'd")
# (u'go', u'down', u'today')
# (u'you', u'enjoy', u'the')
# (u'was', u'funi', u'got')
# (u'oh', u'and', u'bring')
# (u'more', u'import', u'one')
# (u'fun', u'ya', u'know')
# (u'away', u'\U0001f605', u'\U0001f379')
# (u'parti', u'becaus', u'everyon')
# (u'made', u'by', u'my')
# (u'when', u'you', u'stay')
# (u'video', u'where', u'santarouman')
# (u'\U0001f44c', u'\U0001f3fc', u'\u26ab')
# (u'nike', u'is', u'so')
# (u'much', u'love', u'&amp;')
# (u'fun', u'stuff', u'otherwis')
# (u'friend', u'got', u'their')
# (u'day', u'too', u'\U0001f496')
# (u'gir', u'\U0001f389', u'\U0001f60c')
# (u'know', u'how', u'much')
# (u'have', u'cleat', u'but')
# (u'rock', u'at', u'ryan')
# (u'care', u'sled', u'is')
# (u"they'r", u'all', u'onlin')
# (u'spring', u'break', u'fun')
# (u'synovi', u'joint', u'sound')
# (u'wait', u'to', u'go')
# (u'fun', u'be', u'wide')
# (u'\u2764', u'\ufe0f', u'\u2764')
# (u'far', u'at', u'the')
# (u'kangin', u'&amp;', u'heechul')
# (u'the', u'concert', u'bro')
# (u'wave', u'get', u'readi')
# (u'old', u'time', u'when')
# (u'weekend', u'it', u'make')
# (u'and', u'everyon', u'know')
# (u'the', u'hap', u'and')
# (u'&amp;', u'then', u'there')
# (u'list', u'of', u'fixer')
# (u'you', u'all', u'love')
# (u'famili', u'fun', u'run')
# (u'of', u'lacklust', u'mission')
# (u'new', u'nip', u'vinyl')
# (u'fun', u'in', u'poland')
# (u'\U0001f438', u'\u2615', u'\ufe0f')
# (u'day', u'but', u'happi')
# (u'you', u'have', u'fun')
# (u'today', u'and', u'by')
# (u'i', u"don't", u'know')
# (u'fun', u'with', u'me')
# ('<s>', u'just', u'get')
# (u'not', u'a', u'kiss')
# (u'of', u'pinot', u'noir')
# (u'happi', u'birthday', u'aniah')
# (u"don't", u'have', u'a')
# (u'fun', u'&amp;', u'posit')
# (u'(endangered)', u'anim', u'for')
# (u'they', u'all', u'had')
# ('<s>', u'blond', u'hav')
# (u'water', u'sport', u'-')
# (u'you', u'are', u'in')
# (u'of', u'fun', u"can't")
# (u'have', u'a', u'swollen')
# (u'there', u'are', u'no')
# (u'to', u'crowd', u'at')
# (u'will', u'you', u'be')
# (u'ocean', u'of', u'dust')
# (u'isnt', u'forev', u'not')
# (u'fun', u'even', u'of')
# (u'parent', u'the', u'late')
# (u'see', u'the', u'idol')
# (u'birthday', u'anal', u'fun')
# (u'home', u'later', u'x')
# (u'leaast', u'not', u'the')
# (u'the', u'husker', u'and')
# (u'a', u'match', u'\U0001f602')
# ('<s>', u'2nd', u'half')
# (u'to', u'close', u'last')
# ('<s>', u'fun', u'just')
# (u'hutton', u'this', u'year')
# (u'and', u'have', u'a')
# (u'day', u'off', u'i')
# (u'can', u'call', u'her)')
# (u'chef', u'have', u'much')
# (u'wellington', u'coastal', u'ecolog')
# (u'snapchat', u'to', u'actual')
# ('<s>', u'bar', u'in')
# (u'much', u'fun', u'\U0001f602')
# (u'thank', u'for', u'the')
# (u'but', u'you', u'not')
# (u'republican', u'at', u'cpac')
# (u'to', u'carli', u'chaplan')
# (u'hand', u'tri', u'this')
# (u'go', u'creat', u'your')
# (u'class', u'learn', u'their')
# (u'at', u'least', u'i')
# (u"i'm", u'glad', u'it')
# (u'was', u'stood', u'behind')
# (u'wanna', u'go', u'out')
# (u'infect', u'bad', u'back')
# (u'in', u'the', u'end')
# (u'fun', u'stuff', u'h\u2026')
# (u'knightsthi', u'should', u'be')
# (u'wire', u':', u'turn')
# (u'more', u'fun', u'to')
# (u'proud', u'-', u'fixer')
# (u'so', u'far', u'at')
# (u'but', u'i', u'realiz')
# (u'two', u'day', u'in')
# (u'day', u'for', u'the')
# (u'they', u'had', u'like')
# (u'surpris', u'god', u'bless')
# (u'must', u'see', u'tv')
# (u'of', u'trump', u'hair')
# (u'the', u'spirit', u'of')
# (u'not', u'the', u'way')
# ('<s>', u'have', u'fun')
# (u'tri', u'to', u'stop')
# (u'to', u'hear', u'out')
# (u'find', u'a', u'connect')
# (u'of', u'kati', u'packer')
# (u'bf', u'join', u'the')
# (u'is', u'fun', u'especi')
# (u'fun', u'week', u'of')
# (u'im', u'impress', u'is')
# (u'in', u'stock', u'these')
# (u'joke', u'in', u'other')
# (u'and', u'that', u'make')
# (u'set', u'a', u'new')
# ('<s>', u'volleybal', u'tryout')
# (u'on', u'that', u'littl')
# ('<s>', u'polic', u'have')
# (u'\U0001f483', u'\U0001f3fd', u'\U0001f3b6')
# (u'to', u'be', u'a')
# (u'about', u'symmetri', u'at')
# (u'date', u'websit', u'we')
# (u'the', u'good', u'truli')
# (u'your', u'concert', u':(')
# (u'have', u'fun', u'we')
# (u'you', u"can't", u'have')
# (u'am', u'addict', u'to')
# (u'i', u'can', u'read')
# (u'fun', u'friday', u'reward')
# (u'i', u'can', u'say')
# (u'next', u'week', u'\u2708')
# (u'hey', u'need', u'somebodi')
# ('<s>', u'back', u'at')
# (u'talk', u'to', u'who')
# (u'excit', u'and', u'i')
# (u'to', u'love', u'go')
# (u'you', u'for', u'all')
# (u'she', u'the', u'tear')
# (u'be', u'upsid', u'down')
# (u'my', u'40s', u'and')
# (u'emoji', u'actual', u'look')
# (u'fun', u'of', u'arwin')
# (u'it', u'a', u'lot')
# ('<s>', u'keep', u'on')
# (u'be', u'more', u'fun')
# (u'aoc', u'have', u'fun')
# (u'everyon', u'should', u'tri')
# (u'of', u'fun', u'with')
# (u'violenc', u'and', u'someon')
# (u'be', u'in', u'anoth')
# (u"they'r", u'have', u'fun')
# (u'do', u'join', u'us')
# (u'paid', u'instant', u'-')
# (u'this', u'show', u'with')
# (u'of', u'me', u'caus')
# (u'girl', u'made', u'by')
# (u'that', u'in', u'between')
# (u'the', u'fun', u'to')
# (u'thx', u'to', u'spiderman')
# (u'alaskan', u'girl', u'hold')
# (u'on', u'facebook', u'in')
# (u'wierd', u'i', u'know')
# ('<s>', u'had', u'some')
# (u'juici', u'fun', u'with')
# (u'just', u'have', u'to')
# (u'so', u'hard', u'to')
# (u'booth', u'fun', u'farewel')
# (u'realli', u'about', u'tbh')
# (u'be', u'the', u'best')
# (u'whi', u'teenag', u'think')
# (u'free', u'text', u'and')
# ('<s>', u'welp', u'that')
# (u'happi', u'birthday', u'nicol')
# (u'fun', u'play', u'with')
# (u'\U0001f61e', u'\U0001f601', u'\U0001f61e')
# (u'tho', u'hey', u'have')
# (u'anxious', u'for', u'it')
# (u'the', u'japan', u'tour')
# (u'they', u'all', u'love')
# (u'now', u"don't", u'miss')
# (u'week', u'of', u'celebr')
# (u'fasia', u'troponin', u'dorsiflexion')
# (u'-', u'friday', u'spent')
# (u'sooo', u'is', u'it')
# (u'my', u'liptifulintern', u'in')
# (u'3rd', u'and', u'last')
# (u'gr', u'10', u'me')
# (u'truli', u'do', u'die')
# (u'seem', u'to', u'be')
# (u'go', u'to', u'have')
# (u'seuss', u'1950', u'book')
# (u'send', u'free', u'text')
# (u"don't", u'somebodi', u'probabl')
# (u'spent', u'with', u'friend')
# (u'have', u'fun', u'play')
# (u'is', u'that', u'wrong')
# (u'on', u'particip', u'staff')
# (u'get', u'into', u'this')
# (u'\U0001f609', u'\U0001f618', u'\U0001f44d')
# ('<s>', u'no', u'spring')
# (u'to', u'bring', u'up')
# (u'stove', u'from', u'age')
# (u'me', u'is', u'say')
# (u'age', u'16', u'to')
# (u'and', u"we'd", u'all')
# (u'adopt', u'everi', u'dog')
# (u'fun', u'to', u'creat')
# (u'peopl', u'think', u'of')
# (u'basketbal', u'court', u'nice')
# (u'for', u'sunday', u'red')
# (u'see', u'fact', u'taken')
# (u'and', u'you', u'are')
# (u'lie', u'his', u'daughter')
# (u'fact:', u'there', u'are')
# (u'a', u'fun', u'friday')
# (u'i', u'hope', u'it')
# (u'soon', u'\U0001f648', u'\U0001f648')
# (u'famili', u'&gt;', u'game')
# (u'rich', u'fun', u'narrat')
# (u'im', u'scrrame', u'i')
# (u'should', u'be', u'fun')
# (u'onc', u'melt', u'a')
# (u'you', u'look', u'grea')
# (u'are', u'about', u'expression"')
# (u'but', u'no', u'one')
# (u'her', u'new', u'organ')
# (u'was', u'homecom', u'king')
# (u'yup', u'\U0001f4e1', u'\U0001f4fa')
# (u'a', u'chanc', u'we')
# (u'watch', u'not', u'\U0001f62c')
# (u'for', u'special', u'guest')
# (u'i', u'love', u'paint')
# (u'2', u'day', u'vacat')
# (u'hope', u'u', u'have')
# (u'you', u'occupi', u'when')
# (u'frog', u'emoji', u'actual')
# (u'miami', u'to', u'should')
# (u'the', u'boy', u'and')
# (u'mayb', u'we', u'can')
# ('<s>', u'come', u'add')
# (u'rippen', u'on', u'my')
# (u'me', u'for', u'free')
# (u'the', u'proper', u'medic')
# (u'peopl', u'is', u'fun')
# (u'game', u'this', u'season')
# (u'(that', u'has', u'pbs)')
# (u'your', u'chanc', u'to')
# (u'accus', u'of', u'a')
# (u'that', u'i', u'mean')
# (u'to', u'social', u'media')
# (u'where', u'can', u'i')
# (u'"mi', u'workout', u'are')
# (u'will', u'be', u'for')
# (u'even', u'my', u'1')
# (u'vinyl', u'w/', u'flannel')
# (u'night', u'sky', u'912')
# (u'fun', u'today', u'w/@gwynethpaltrow')
# ('<s>', u'i', u"can't")
# (u'"if', u'i', u'ran')
# ('<s>', u'date', u'someon')
# (u'damn', u'fun', u'you')
# (u'lil', u'bro', u'show')
# (u'for', u'bern-', u'taco')
# (u'in', u'go', u'do')
# (u'have', u'a', u'fun')
# (u'your', u'team', u'the')
# (u'one', u'of', u'my')
# (u'basketbal', u'probabl', u'gold')
# (u'now', u'you', u'also')
# (u'so', u'far', u'lot')
# (u'call', u'911', u'for')
# (u'print', u'out', u'these')
# (u'get', u'some', u'fresh')
# ('<s>', u'hahahaha', u'that')
# (u'fit', u'to', u'me')
# (u'with', u'rich', u'fun')
# (u'ad', u'this', u'to')
# (u'up:', u'peeptini', u'style:')
# (u'agre', u'watch', u'his')
# (u'for', u'the', u'snapchat')
# (u'maichard', u'momentg', u'them')
# (u'i', u"don't", u'even')
# (u'realiz', u'that', u'i')
# (u'michigan', u'-', u'wtf')
# (u'fun', u'and', u'more')
# (u'and', u'a', u'long')
# (u'origin', u'from', u'dr')
# (u'back', u'is', u'depress')
# (u'teenag', u'think', u'it')
# (u'tonight', u'have', u'a')
# (u'this', u'date', u'websit')
# (u'fun', u'\U0001f602', u'\U0001f602')
# (u'some', u'casual', u'fun')
# (u'nine-nin', u's01e09', u'fun')
# (u'pollen', u'is', u'fun')
# (u'repres', u'my', u'5-year')
# (u'&amp;', u'fun', u'to')
# (u'was', u'made', u'up')
# ('<s>', u'onight', u'was')
# (u'some', u'newli', u'releas')
# (u'here', u'to', u'have')
# (u'us', u'on', u'our')
# (u'my', u'new', u'book--which')
# (u'in', u'short:', u'i')
# (u'\U0001f3fc', u'\U0001f334', u'\u2600')
# (u'have', u'unlimit', u'happi')
# (u'your', u'go', u'to')
# (u'you', u'guy', u'were')
# (u'when', u'im', u'have')
# ('<s>', u'i', u'know')
# ('<s>', u'een', u'has')
# ('<s>', u'may', u'you')
# (u'most', u'fun', u'and')
# (u'have', u'fun', u'take')
# (u'have', u'more', u'fun')
# (u'in', u'your', u'inbox')
# (u'much', u'fun', u'gonna')
# (u'allow', u'2', u'explain')
# (u'bushido', u'blade', u'was')
# (u'get', u'readi', u'to')
# (u'at', u'chaz', u'first')
# ('<s>', u'anoth', u'in')
# (u'you', u'can', u'call')
# (u"i'v", u'enjoy', u'this')
# (u'all', u'by', u'myself')
# (u'to', u'mom', u'who')
# (u'been', u'fun', u'i')
# (u'\U0001f49e', u'have', u'fun')
# (u'fun', u'fact', u'book')
# (u'come', u'out', u'soon')
# (u'this', u'tour', u':/')
# (u'in', u'the', u'4th')
# (u"i'm", u'like', u'how')
# (u'excit', u'while', u'it')
# (u'for', u'but', u'now')
# (u'have', u'a', u'better')
# ('<s>', u'i', u'wish')
# (u'today', u'w/', u'she')
# (u'northang', u'abbey', u'by')
# (u'fun', u'time', u'he')
# (u'allahhhhhh', u'im', u'so')
# (u'(and', u'michelle)', u'were')
# (u'star', u'of', u'the')
# (u'worth', u'the', u'while')
# (u'want', u'to', u'go')
# (u'thank', u'so', u'much')
# (u'have', u'fun', u'\U0001f602')
# (u'concert', u'bro', u"i'm")
# (u'creat', u'new', u'beat')
# (u'and', u'the', u'hood')
# (u'extens', u'compil', u'with')
# (u'love', u'&amp;', u'respect')
# (u'around', u'lol', u'i')
# (u'oh', u'man', u'so')
# (u'to', u'let', u'play')
# (u'hot', u'or', u'not')
# (u'rememb', u'not', u'even')
# (u'a', u'fun', u'pictur')
# (u'day', u'the', u'girl')
# (u'but', u'it', u'okay')
# (u'delia', u'sherman', u'via')
# (u'the', u'same', u'color')
# (u'have', u'fun', u'in')
# (u'late', u'show', u'was')
# ('<s>', u'who', u"wouldn't")
# (u'happi', u'weekend', u'everyon')
# (u'fluff', u'for', u'fun')
# (u'are', u'too', u'good')
# (u'too', u'but', u'i')
# (u'ani', u'idea', u'what')
# (u'be', u'honest', u'did')
# (u'it', u'so', u'so')
# ('<s>', u'summer', u'is')
# (u'girl', u'call', u'911')
# (u'to', u'everyon', u'who')
# (u'onli', u'for', u'her')
# (u'full', u'of', u'fun')
# (u'well', u'done', u'guy')
# (u'year', u'make', u'it')
# (u'a', u'surrog', u'for')
# (u'just', u'taught', u'a')
# (u'that', u'have', u'fun')
# (u'holiday', u'to', u'plan')
# (u'my', u'midterm', u'tomorrow')
# (u'on', u'our', u'facebook')
# (u'bc', u'made', u'it')
# (u'wanna', u'do', u'someth')
# ('<s>', u'what', u'do')
# (u'full', u'of', u'holiday')
# (u'on', u'over', u'to')
# (u'by', u'carolin', u'norsk')
# (u'guess', u'it', u'will')
# (u'chat', u'now', u"don't")
# (u'fun', u'gamei', u'alway')
# (u"hey'r", u'so', u'fun')
# (u'for', u'voguebut', u'she')
# ('<s>', u'nice', u'have')
# (u'a', u'fun', u'and')
# (u'haryana', u'feel', u'of')
# (u'class', u'let', u'me')
# ('<s>', u'his', u'weekend')
# (u'look', u'it', u'me')
# (u'wanna', u'have', u'fun')
# (u'bred', u'it', u'that')
# (u'inde', u'should', u'one')
# (u'high', u'speed', u'camera')
# (u'cute', u'get', u'one')
# (u'after', u'school', u'after')
# (u'it', u'was', u'worth')
# (u'get', u'paid', u'instant')
# (u'some', u'fun', u'thing')
# (u'young', u'team', u'will')
# (u'all', u'those', u'shitti')
# (u'a', u'teacher', u'(sorta)')
# (u'get', u'fun', u'littl')
# (u'for', u'io', u'whi')
# (u'with', u'all', u'the')
# (u'like', u'to', u'person')
# (u'her', u'lunch', u"wasn't")
# (u'help', u'with', u'the')
# (u'ice', u'at', u'all')
# (u'had', u'fun', u'with')
# ('<s>', u'more', u'fun')
# ('<s>', u'hahahaha', u'still')
# ('<s>', u'when', u'you')
# (u'and', u'blue', u'ivi')
# (u'and', u'someon', u'who')
# (u'yass', u'\U0001f602', u'\U0001f60f')
# (u'as', u'have', u'fun')
# (u'up', u'at', u'angela')
# (u'daughter', u'vote', u'alden')
# (u'oday', u'was', u'so')
# (u'my', u'bridesmaid', u"it'll")
# ('<s>', u'on', u'the')
# (u'all', u"i'd", u'just')
# (u'a', u'game', u'to')
# (u'make', u'these', u'we')
# (u'there', u'for', u'the')
# (u'have', u'fun', u'good')
# (u'into', u'this', u'weekend')
# (u'of', u"'s", u'hair')
# (u"i'm", u'so', u'impress')
# (u'pirat', u'and', u'flirti')
# (u'and', u'you', u'guy')
# ('<s>', u'"to', u'love')
# (u'spoiler', u'are', u'fun')
# (u'just', u'have', u'fun')
# (u'simpson:', u'"you', u'guy')
# (u'this', u'movi', u'for')
# (u'band', u'from', u'a')
# (u'be', u'stood', u'up')
# (u'anoth', u'fun', u'episod')
# (u'colleg', u'girl', u'all')
# (u'the', u'fun', u'new')
# (u'much', u'abt', u'you')
# (u'\u2661\u2661\u2661', u'i', u'hope')
# (u'fun', u'allahhhhhh', u'im')
# (u'onli', u'fun', u'when')
# (u'night', u"we'r", u'gonna')
# (u'thai', u'friend', u'visit')
# (u'game', u'could', u'lose')
# (u'lesson', u'you', u"don't")
# (u'fun', u'book', u'to')
# ('<s>', u'f/a', u'for')
# (u'adventur', u'with', u'all')
# (u'a', u'stranger', u'a')
# (u'on', u'craft', u'knife')
# (u'cours', u'ion', u'care')
# (u'start', u'yet', u'and')
# (u'ealli', u'enjoy', u'the')
# (u'forward', u'to', u'have')
# (u'a', u'fun', u'job')
# (u'so', u'sexi', u'fun')
# (u'piec', u'of', u'shit')
# (u'and', u'masquerad', u'mask')
# (u'famili', u'with', u'a')
# (u'sound', u'like', u'they')
# (u'it', u'summer', u'ye')
# (u'tomorrow', u'head', u'on')
# (u'the', u'mind', u'and')
# (u'wait', u'for', u'tuesday')
# (u'week', u'\U0001f3dd', u'detail')
# (u'do', u'you', u'do')
# (u'48\u2605', u'of', u'400+')
# (u'slide', u'photo', u'state')
# (u'fun', u'prize', u'pack')
# (u'what', u'happen', u'on')
# (u'coupl', u'hoe', u'to')
# (u'blue', u'\U0001f60d', u'\U0001f44c')
# (u'fun', u'of', u'someon')
# (u'colleg', u'whore', u'have')
# (u'funsometim', u'you', u'just')
# (u'have', u'kong', u'squeaker')
# (u'i', u'give', u'variant')
# (u'made', u'huge', u'\u2026')
# (u'be', u'on', u'cam')
# (u'polar', u'game', u'too')
# (u'i', u"can't", u'have')
# (u'22', u'the', u'good')
# ('<s>', u'that', u'1')
# (u'thrower', u'ran', u'the')
# (u'such', u'fun', u'thx')
# (u'bed', u'\u263a', u'\ufe0f')
# (u'the', u'hood', u'girl')
# (u'interview', u'video', u'on')
# (u'noooo', u'one', u'to')
# (u'to', u'focus', u'on')
# (u'idk', u'littl', u'thing')
# (u'fun', u'interact', u'with')
# (u'shit', u'i', u'liter')
# (u'furnitur', u'shop', u'is')
# (u'fun', u'syd', u'\U0001f498')
# (u'mind', u'for', u'your')
# (u'and', u'act', u'like')
# (u'ahhh', u'i', u'rememb')
# (u'in', u'the', u'fun')
# (u'the', u'stori', u'behind')
# (u'true', u'lol', u'it')
# (u'is', u'not', u'so')
# (u'you', u'said', u'that')
# (u'power', u'word', u'list')
# (u'stream', u'with', u'you')
# (u'fun', u'\U0001f60a', u'\U0001f602')
# (u'be', u'for', u'my')
# (u'jakarta', u'realli', u'sad')
# (u'teach', u'tonight', u'-')
# (u'our', u'have', u'fun')
# (u'like', u'to', u'just')
# (u'of', u'celebr', u'read')
# (u'-', u"she'll", u'lead')
# (u'kid', u'a', u'lesson')
# ('<s>', u'guess', u'we')
# (u'spiderman', u'&amp;', u'frozen')
# (u'i', u'think', u"she'll")
# (u'you', u'so', u'much')
# (u';-)', u'3', u'inch')
# (u'it', u'so', u'great')
# (u'activ', u'kid', u'will')
# (u'fun', u'with', u'lulu')
# (u'no', u'sun', u'which')
# (u"ain't", u'it', u'fun')
# (u'\u263a', u'\ufe0f', u'\u263a')
# (u'was', u'fun', u'as')
# ('<s>', u'write', u'name')
# (u'reoccur', u'skit', u'on')
# (u'fun', u'for', u'like')
# (u'cabinet', u'with', u'\U0001f618')
# (u'with', u'you', u'in')
# (u'cpac', u'is', u'fun')
# (u'to', u'the', u'state')
# (u'thank', u'you', u'all')
# (u'worri', u'about', u'the')
# ('<s>', u'do', u'you')
# (u'soooo', u'much', u'fun')
# (u'one', u'thing', u'to')
# ('<s>', u'dara', u'is')
# (u'has', u'fun', u'and')
# (u'fun', u'fox', u"i'm")
# (u'new', u'fun', u'cute')
# (u'pennington', u'proud', u'-')
# (u'the', u'wrong', u'way')
# (u'fun', u'of', u'product')
# (u'to', u'keep', u'come')
# (u'it', u'time', u"i'm")
# (u'now', u'it', u'time')
# (u'south', u'is', u'still')
# (u'fun', u'call', u'today')
# (u'a', u'trooper', u'&amp;')
# (u'makenit', u'fun', u'to')
# (u'karaok', u'away', u'\U0001f605')
# (u'laboum', u'alway', u'seem')
# (u'have', u'you', u'tri')
# (u'get', u'to', u'fuck')
# (u'in', u'walki', u'talki')
# (u'\U0001f49b', u'you', u'should')
# (u'me', u'make', u'fun')
# (u'the', u'fgc', u'top')
# (u'with', u'my', u'roomi')
# (u'hamilton', u'central', u'citi')
# (u'for', u'destini', u'drop')
# (u'fun', u'defend', u'the')
# (u'to', u'see', u'where')
# (u'day', u'at', u'hot')
# (u'look', u'like', u'leia')
# ('<s>', u'hope', u'everyon')
# (u'put', u'on', u'that')
# (u'visit', u'the', u'place')
# (u'\ufe0f', u'\u2764', u'\ufe0f')
# (u'this', u'sure', u'sound')
# ('<s>', u'it', u'friday')
# (u'you', u'guy', u'can')
# (u'it', u'the', u'fun')
# (u'frank', u'im', u'impress')
# (u'nice', u'the', u'basketbal')
# (u'leonard', u'pilot', u'great')
# (u'stupid', u'fun', u'idea')
# (u'we', u'all', u'use')
# (u'tonight', u'for', u'casual')
# (u'fun-fil', u'night', u'benefit')
# (u'est', u'(6:00', u'pm')
# (u'a', u'pleaser', u'i')
# (u'she', u'becom', u'the')
# (u'lulu', u'&amp;', u'laura')
# (u'im', u'think', u'about')
# (u'fun', u'today', u'congrat')
# (u'1', u'is', u'fun')
# (u'that', u"doesn't", u'find')
# (u'yourself', u'then', u'you')
# (u'40s', u'and', u"couldn't")
# (u'notic', u'my', u'bag')
# (u'tri', u'this', u'simpl')
# (u'$', u'bail', u'better')
# (u'simpli', u'touch', u'the')
# (u'pictur', u'in', u'guatemala')
# (u'and', u'miss', u'you')
# (u'a', u'few', u'charact')
# (u'some', u'of', u'the')
# (u'with', u'your', u'phone')
# (u'program', u'plan', u'after')
# (u'overslept', u'cut', u'finger')
# ('<s>', u'fun', u'date')
# (u'such', u'a', u'success')
# (u'fun', u'circuit', u'activity:')
# (u'birthday', u'may', u'be')
# (u'tonit', u'was', u'fun')
# ('<s>', u'alrighti', u'have')
# (u"wasn't", u'as', u'fun')
# (u'home', u'to', u'join')
# (u'i', u'was', u'no')
# (u'do', u'a', u'big')
# (u'3', u'have', u'fun')
# (u'had', u'too', u'much')
# (u'app', u'so', u'much')
# (u'and', u'develop', u'look')
# ('<s>', u"i'm", u'addict')
# (u'you', u"don't", u'make')
# ('<s>', u'omorrow', u'is')
# (u'stream', u'that', u'in')
# (u'6', u'pm', u'on')
# (u'first', u'wrestl', u'mee')
# (u'newest', u'commit', u'will')
# (u'as', u'ego', u'that')
# (u'out', u'lane', u'bryant')
# (u'is', u'tri', u'to')
# (u'out', u'of', u'a')
# (u'go', u'to', u'corner')
# (u'gut', u'as', u"i'v")
# (u'pro', u'my', u'gfx')
# (u'hahahahaha', u'\U0001f606', u'\U0001f605')
# (u'play', u'it', u'no\u2026')
# (u'and', u'relax', u'weekend')
# (u'it', u'just', u'fun')
# (u'is', u'incred', u'badass')
# (u'for', u'me', u'updat')
# (u'learn', u'about', u'symmetri')
# (u'you', u'just', u'need')
# (u'of', u'limb', u'if')
# (u'alway', u'fun', u'but')
# (u'&amp;', u'frozen', u'elsa')
# (u'bday', u'bash', u'cafe')
# (u'ornament', u'princess', u'$')
# (u'by', u'sasi', u'and')
# (u'pst)', u'see', u'you')
# (u'i', u'search', u'through')
# (u'definit', u'need', u'peopl')
# (u'fun', u'freakgo', u'watch')
# (u'that', u'i', u'have')
# (u'day', u'it', u'fun')
# (u'readi', u'for', u'surf')
# (u'morn', u'as', u'she')
# (u'imma', u'skip', u'next')
# (u'margarita', u'and', u'you')
# (u'you', u'went', u'to')
# (u'to', u'make', u'it')
# (u'bad', u'v', u'fun')
# (u'famili', u'sound', u'like')
# (u'so', u'cute', u'get')
# (u'hopkin', u'||', u'sexist')
# (u'the', u'ice', u'at')
# (u'show', u'on', u'sunday')
# (u'your', u'hair', u'match')
# (u'yes', u'have', u'fun')
# (u'three', u'band', u'did')
# (u'so', u'so', u'much')
# (u'with', u'an', u'atheist')
# (u'in', u'for', u'naughti')
# (u'&amp;', u'threw', u'it')
# (u'on', u'appar', u'order')
# ('<s>', u'so', u'de')
# ('<s>', u'you', u'listen')
# (u'which', u'is', u'alway')
# (u'in', u'the', u'fl')
# (u'love', u'yourself', u'bc')
# (u'that', u'fight', u'breakdown/dick')
# (u'same', u'boat', u'what')
# ('<s>', u"i'v", u'enjoy')
# (u'at', u'new', u'washington')
# (u'of', u'these', u'more')
# (u'have', u'fun', u'tonight')
# (u'come', u'with', u'me')
# (u'school', u'after', u'school')
# (u'social', u'media', u'i')
# (u'veri', u'touch', u'story\u2026')
# ('<s>', u'was', u'spot')
# (u'it', u'tomorrow', u'morn')
# (u'a', u'year', u'\U0001f389')
# (u'how', u'are', u'you')
# (u'michelle)', u'were', u'fun')
# (u'bit', u'but', u'be')
# (u'all', u'done', u'up')
# (u"i'm", u'pray', u'on')
# (u'anoth', u'in', u'a')
# (u'of', u'ppl', u'magic')
# (u'member', u'it', u'school')
# (u'those', u'time', u'back')
# (u'have', u'fun', u'leav')
# (u'creat', u'a', u'fun')
# ('<s>', u'i', u'need')
# (u'back', u'at', u'work')
# (u'odp', u'and', u'alway')
# (u'with', u'young', u'volunt')
# (u'all', u'of', u'my')
# (u'mean', u'an', u'overwhelm')
# (u'look', u'great', u'will')
# ('<s>', u'75%~', u'creat')
# (u'see', u'me', u'click')
# (u'deni', u':)', u'it')
# (u'movement', u'creat', u'by')
# (u'just', u'watch', u'tv')
# (u'meet', u'you', u"i'v")
# (u'book', u'about', u'lion')
# (u'lot', u'harder', u'to')
# (u'i', u'wish', u'peopl')
# (u'everyth', u'fun', u'kind')
# (u"we'r", u'have', u'fun')
# (u'that', u'littl', u'guy')
# ('<s>', u'new:', u'experi')
# (u'fun', u'fact', u'for')
# (u'brighter', u'then', u'the')
# (u'got', u'a', u'c+')
# ('<s>', u'yay', u'tonight')
# (u"can't", u'have', u'fun')
# ('<s>', u'your', u'chanc')
# ('<s>', u'yah', u'gonna')
# (u'till', u'some', u'new')
# (u'through', u'it', u'is')
# (u'ump', u'is', u'like')
# (u'my', u'fan', u'get')
# (u'said', u'latex', u"wasn't")
# (u'invit', u'me', u'to')
# (u'exampl', u'have', u'fun')
# (u'her', u'thai', u'friend')
# ('<s>', u'6', u'holiday')
# (u'thank', u'for', u'host')
# (u'it', u'bc', u'it')
# (u'your', u'and', u'head')
# (u'i', u'miss', u'yix')
# ('<s>', u'dinner', u'is')
# (u'eye', u'fool', u'after')
# (u'sinistr', u'part', u'5')
# (u'support', u"you'v", u'given')
# ('<s>', u'low', u'limit')
# (u'safe', u'relax', u'&amp;')
# (u'to', u'see', u'your')
# (u'fuck', u'you', u'guy')
# (u'that', u'was', u'a')
# (u'mayb', u'wayn', u'knight')
# (u'w/', u'bore', u'stationari')
# (u'grip', u'take', u'a')
# (u'he', u'real', u'stori')
# (u'in', u'life', u'you')
# (u'today', u'&amp;', u'\U0001f49b')
# (u'court', u'nice', u'the')
# (u'bore', u'lone', u'click')
# (u'to', u'person', u'thank')
# (u'who', u'is', u'readi')
# (u'realli', u'polar', u'game')
# (u'this', u'fun', u'crew')
# (u'have', u'funstay', u'trueb')
# (u'yes', u'that', u'sound')
# (u'you', u'think', u'it')
# (u'the', u'major', u'of')
# (u'your', u'thumb', u'green')
# (u'a', u'fun', u'back')
# (u'fun', u'day', u'-')
# (u'for', u'a', u'chanc')
# (u'watch', u'this', u'it')
# (u'no', u'leader', u'in')
# (u'think', u'i', u'will')
# (u'\u2764', u'\ufe0f', u'\U0001f46b')
# (u'2nd', u'half', u'start')
# (u'tough', u'one', u'pizza')
# (u'guess', u'be', u'stood')
# (u'kind', u'of', u'play#yeay')
# (u'member', u'who', u'are')
# (u'young', u'again', u'whenev')
# (u'win', u'prize', u'plan')
# ('<s>', u'une', u'in')
# (u'fun', u'steampunk', u'short')
# (u'a', u'twat', u'but')
# (u'all', u'part', u'of')
# (u'fun', u'one', u'for')
# (u'look', u'fun', u'to')
# ('<s>', u'to', u'mom')
# (u'again', u'and', u'that')
# (u'super', u'busi', u'visit')
# (u'and', u'doubl', u'jeopar\u2026')
# (u'on', u'tonight', u'must')
# (u'to', u'girl', u'just')
# (u'bolder', u'time', u'to')
# (u'\u2600', u'\ufe0f', u'\U0001f60e')
# ('<s>', u'wud', u'challeng')
# (u'media', u'i', u'just')
# (u'have', u'a', u'ticket')
# (u'typo', u'make', u'pun')
# (u'personality:', u'a', u'social')
# (u'with', u'her', u'pussi')
# ('<s>', u'final', u'home')
# (u'game', u'happi', u'weekend')
# (u'me', u'feel', u'like')
# (u'bsnyc', u'friday', u'fun')
# (u'cake', u'for', u'rachel')
# (u'so', u'much', u'salt')
# (u'on', u'game', u'and')
# (u'while', u'rais', u'fund')
# (u'make', u'it', u'worth')
# (u'film', u'as', u'part')
# (u'download', u'from', u'and')
# (u'it', u'cute', u'when')
# (u"i'm", u'alreadi', u'anxious')
# (u'what', u'could', u'be')
# (u'anyth', u'for', u'you')
# (u'taken', u'out', u'of')
# (u'but', u'mayb', u'not')
# (u'haha', u'i', u"don't")
# (u'listen', u'learn', u'repeat')
# (u'win', u'ticket', u'to')
# (u'dick', u'haha-', u'fun')
# (u'you', u'there', u'\U0001f60a')
# (u'need', u'need', u'money')
# (u'happi', u'birthday', u'to')
# (u"don't", u'need', u'need')
# (u'got', u'in', u'that')
# (u'of', u'thing*', u'me')
# (u'got', u'a', u'fun')
# (u'got', u'some', u'fun')
# (u'tryout', u'with', u'valeri')
# (u'littl', u'black', u'dress')
# (u'help', u'student', u'hack')
# (u'it', u'the', u'same')
# (u'turn', u'out', u'watch')
# (u'for', u'team', u'also')
# (u'me', u'for', u'so')
# (u'to', u'write', u'it')
# (u'timmi', u'like', u'do')
# (u'for', u'kath', u'and')
# (u'friend', u'with', u'all')
# (u'fun', u'but', u'too')
# ('<s>', u'psst', u'\u2764')
# (u'miss', u'all', u'involv')
# (u'me', u'a', u'video')
# (u'of', u'fun', u'and')
# (u'i', u'promis', u"i'm")
# (u'\U0001f46b', u'\U0001f1ef\U0001f1f5', u'maichardseizethemo')
# (u'who', u'readi', u'to')
# (u'\U0001f44d', u'\U0001f609', u'\U0001f31a')
# ('<s>', u'yay', u'thank')
# (u'can', u'tri', u'them')
# (u'prize', u'pack', u'htt\u2026')
# (u'realli', u'a', u'"maine"event&amp;hop')
# (u'a', u'veri', u'veri')
# (u'talk', u'abt', u'stab')
# ('<s>', u'pleas', u'eat')
# (u'feel', u'like', u'i')
# ('<s>', u'hat', u'fun')
# (u'fun', u'and', u'easi')
# (u'with', u'the', u'shave)')
# (u'nip', u'vinyl', u'w/')
# (u'you', u'take', u'way')
# (u'you', u'all', u'\U0001f499')
# (u'maaaaad', u'fun', u'ratchet')
# (u'it', u'to', u'end')
# (u'hood', u'ornament', u'princess')
# (u'and', u'my', u'whole')
# (u'order', u'from', u'the')
# (u'we', u'were', u'young')
# (u'my', u'famili', u'\U0001f607')
# (u'throw', u'a', u'small')
# (u'a', u'fun', u'day')
# (u'tinder', u'for', u'alaskan')
# (u'you', u'are', u'look')
# (u'and', u'your', u'husband')
# (u'so', u'fun', u'good')
# (u'effect', u'mastermind', u'group:')
# (u'fun', u'until', u'i')
# (u'mom', u'got', u'all')
# (u'all', u'your', u'question')
# (u'know', u'how', u'to')
# (u'i', u'offer', u'get')
# ('<s>', u'bram', u'stoker')
# (u'this', u'season', u'should')
# (u'much', u'fun', u'chat')
# (u'train', u'with', u'our')
# (u'to', u'play', u'in')
# (u'"so', u'much', u'fun"')
# (u'sum', u'new', u'kinki')
# (u'again', u'happi', u'birthday')
# (u'alarm', u"wasn't", u'set')
# (u'booth', u'for', u'the')
# (u'your', u'-', u'is')
# (u'my', u'first', u'year')
# (u'show', u'so', u'let')
# (u'never', u'cross', u'my')
# (u'pizza', u'or', u'taco')
# (u'need', u'anoth', u'weekend')
# (u'fun', u'of', u'yourself')
# (u'quest;', u'have', u'fun')
# (u'your', u'hand', u'tri')
# (u'fun', u'game', u'where')
# (u'like', u'i', u'am')
# (u'hella', u'fun', u'laugh')
# (u'fun', u'to', u'watch')
# (u'servic', u'sat', u'3/26')
# (u'ivi', u'are', u'in')
# (u'fun', u'shoot', u'with')
# (u'understood', u'how', u'fun')
# (u'i', u'take', u'a')
# (u'happen', u'here', u'at')
# (u'to', u'frog', u'with')
# (u'it', u'to', u'the')
# (u'have', u'fun', u'so')
# (u'amaz', u'photo', u'&amp;')
# (u'anim', u'shelter', u'and')
# (u'\U0001f37e', u'\U0001f3b6', u'\U0001f48b')
# (u'come', u'check', u'us')
# (u'fun', u'bun', u'trill')
# (u'fun', u'i', u'freestyl')
# ('<s>', u'be', u'singl')
# (u'expect', u'it', u'to')
# (u'a', u'cours', u'of')
# (u'the', u'darl', u'pavillion')
# ('<s>', u'good', u'news')
# (u'the', u'one', u'make')
# (u"can't", u'even', u'have')
# (u'free', u'time', u'make')
# (u'my', u'review', u'of')
# (u'dure', u'sound', u'check')
# (u'fun', u'and', u'a')
# (u'tho', u'hun', u'\U0001f618')
# (u'of', u'game', u'of')
# (u'famili', u'tonight', u'but')
# (u'want', u'to', u'third')
# (u'for', u'a', u'new')
# (u'fun', u'make', u'cool/retard')
# (u'now', u'for', u'some')
# (u'profession', u'hope', u'to')
# (u'is', u'fun', u'\U0001f612')
# (u'-', u'the', u'west')
# (u'her', u';-)', u'3')
# (u'phx', u'next', u'week')
# (u'have', u'fun', u':-)')
# (u'today', u'\U0001f60d', u'check')
# (u'major', u'of', u'the')
# (u'that', u'part', u"isn't")
# (u'kati', u'hopkin', u'||')
# (u'made', u'it', u'so')
# (u'for', u'the', u'discuss')
# (u'face', u'and', u'his')
# (u'on', u'age7', u'=')
# ('<s>', u'hide', u'your')
# (u'get', u'me', u'a')
# (u'for', u'anoth', u'fun')
# (u'allow', u'to', u'use')
# (u'&amp;', u'grow', u'with')
# (u'miner', u'water', u'and')
# (u'again', u'today', u'which')
# (u'weekend', u'oh', u'the')
# (u'action', u'and', u'fun')
# (u'reminisc', u'back', u'to')
# (u'be', u'singl', u'so')
# (u'fun', u'memori', u'this')
# (u'everi', u'time', u'i')
# (u'is', u'alway', u'a')
# (u'it', u'simpl', u'and')
# (u'rememb', u'run', u'the')
# (u'be', u'head', u'home')
# (u'fun', u'in', u'a')
# (u'of', u'\U0001f601', u'mag')
# (u'fun', u'with', u'this')
# (u'for', u'fun', u"you'r")
# (u'superhero', u'fun', u'in')
# (u'lufia', u'ii', u'rise')
# (u'it', u'one', u'thing')
# (u'limit', u'bj', u'is')
# (u'guitar', u'school', u'right')
# (u'have', u'more', u'stress')
# (u'at', u'school', u'becaus')
# (u'get', u'free', u'time')
# ('<s>', u'how', u'much')
# (u'fun', u'in', u'my')
# (u'guy', u'do', u'anyth')
# (u'you', u'all', u'had')
# (u'ambassador', u'for', u'fun')
# (u'rememb', u'those', u'fun')
# (u'get', u'taken', u'the')
# (u'af', u'bc', u'she')
# (u'this', u'i', u"can't")
# (u'play', u'with', u'her')
# (u'so', u'much', u'fun')
# ('<s>', u'later', u'11pm')
# (u'love', u'go', u'into')
# (u'fun', u'via', u'sandytoesmom')
# (u'of', u'cook', u'learn')
# (u'i', u'swear', u'peopl')
# (u'peopl', u'repli', u'to')
# (u'etweet', u'okkinderhook', u'(@okkinderhook):')
# (u'hope', u'you', u'all')
# (u'connect', u'for', u'discreet')
# (u'but', u"i'm", u'come')
# (u'start', u'have', u'with')
# (u'to', u'our', u'have')
# (u'we', u'could', u'have')
# (u'of', u'dust', u'avail')
# (u'craft', u'food', u'and')
# (u'friend', u'chantelle_kerri', u'and')
# ('<s>', u'send', u'so')
# (u'all', u'have', u'fun')
# (u'"kar-mi"', u'it', u'a')
# (u'ack', u'practic', u'in')
# (u'u', u'did', u'not')
# ('<s>', u'messag', u'from')
# ('<s>', u'hat', u'was')
# ('<s>', u'attent', u':')
# ('<s>', u'whenev', u"i'm")
# (u'this', u'so', u'fun')
# (u'game', u'where', u'i')
# (u'who', u'was', u'stood')
# (u'fun', u'and', u'everyth')
# (u'he', u'realli', u'is')
# (u'it', u'\U0001f64f', u'\U0001f3fe')
# (u'could', u'be', u'so')
# (u'stay', u'on', u'game')
# (u'in', u'your', u'movi')
# (u'me', u'4', u'sum')
# (u'girl', u'hold', u'dead')
# (u'to', u'kick', u'it')
# (u'a', u'new', u'seri')
# (u'that', u':)', u'it')
# (u'book--which', u"isn't", u'even')
# (u'bridg', u'part', u'for')
# (u'so', u'fun', u'i')
# (u'play', u'pop', u'mayb')
# (u'guest', u'merch', u'and')
# (u'hs', u'jv', u'lacross')
# (u'impress', u'is', u'a')
# (u'dorsiflexion', u'and', u'synovi')
# (u'rod', u'finna', u'have')
# (u'like', u'such', u'a')
# (u'mattersth', u'fun', u'stuff')
# (u'poker', u'look', u'fun')
# ('<s>', u"you'll", u'be')
# (u'&amp;', u'simpl', u'social')
# (u'was', u'26)', u'yep')
# (u'are', u'fun', u'it')
# (u'come', u'down', u'to')
# (u'go', u'do', u'fun')
# (u'madison', u'favorit', u'ice')
# (u'that', u'1', u'is')
# (u'ya', u'know', u'to')
# (u'kawan', u'lelaki', u'as')
# (u'17', u'&amp;', u'18')
# (u'just', u'went', u'to')
# (u'agent', u'fit', u'(shutdown')
# (u'ps1', u'pad', u'and')
# (u'to', u'walk', u'a')
# (u'have', u'depress', u'as')
# (u'the', u'potenti', u'of')
# ('<s>', u'come', u'and')
# (u'a', u'cute', u'fun')
# ('<s>', u'disney', u'is')
# (u'but', u'let', u'hangout')
# (u'yet', u'to', u'meet')
# (u'anyway', u'\U0001f618', u'have')
# (u'the', u'one', u'get')
# (u'all', u'that', u'matter')
# ('<s>', u'karaok', u'in')
# (u'shoot', u'this', u'in')
# (u'nearbi', u'when', u'you')
# (u'serious', u'check', u'out')
# (u'interview', u'with', u'the')
# (u'all', u'season', u'and')
# (u'dara', u'is', u'have')
# ('<s>', u'where', u'can')
# (u'late', u'at', u'night')
# (u'fact:', u'the', u'state')
# (u'other', u'home', u'and')
# (u'interact', u'with', u'the')
# (u'overcast', u'network', u'or')
# (u'open', u'day', u'it')
# (u'make', u'my', u'new')
# (u'cassidi', u'it', u'been')
# (u'in', u'order', u'to')
# (u'someon', u'who', u'just')
# (u'the', u'site', u'now')
# (u'in', u'ulta', u'tbh')
# (u'so', u'much', u'abt')
# (u'run', u'rampant', u'at')
# (u'been', u'a', u'fun')
# (u'fun', u'healthi', u'day')
# ...
# (u'have', u'fun', u'i')
# (u'fun', u'i', u'just')
# (u'and', u'mac', u'10')
# (u'have', u'fun', u';)')
# ('<s>', u'make', u'for')
# (u'tri', u'these', u'crunch-fre')
# (u'ate', u'\U0001f499', u'kathniel')
# (u'fun', u'just', u'watch')
# (u'af', u'\U0001f389', u'\U0001f389')
# (u"isn't", u'much', u'fun')
# (u'a', u'group', u'fuck')
# (u'i', u'hope', u'yasmin')
# (u'the', u'place', u'you')
# (u'leia', u'and', u'maggi')
# ('<s>', u'one', u'last')
# (u'"', u'\U0001f914', u'\U0001f914')
# (u'he', u'movi', u'is')
# (u'song', u'queen', u'slay')
# (u'i', u'am', u'bc')
# (u'of', u'the', u'best')
# (u'and', u'nate', u'\U0001f64c')
# (u'i', u'hard', u'know')
# (u'was', u'fun', u'but')
# (u'with', u'the', u'boy')
# (u'honcho', u'gang', u'\U0001f525')
# (u'just', u'for', u'fun')
# (u'skin', u'care', u'and')
# (u'sydney', u'i', u'hope')
# (u'your', u'movi', u'is')
# (u'twat', u'but', u'you')
# (u'lol', u'cannot', u'wait')
# ('<s>', u'miami', u'to')
# (u'the', u'rest', u'hope')
# (u'make', u'us', u'manufactur')
# (u'of', u'my', u'sister')
# (u'you', u'oh', u'man')
# (u'show', u'with', u'one')
# (u'shanell', u'(jessica', u'help')
# (u'such', u'an', u'amaz')
# (u'clementin', u'i', u'sent')
# ('<s>', u'it', u'back')
# ('<s>', u'3-gun', u'match')
# (u'got', u'hit', u'by')
# (u'troponin', u'dorsiflexion', u'and')
# (u'japan', u'tour', u'video')
# (u'campaign', u'for', u'had')
# (u'heechul', u'have', u'fun')
# (u'\u2764', u'\u2764', u'\u2764')
# (u'fun', u'of', u"'s")
# (u'like', u'so', u'much')
# ('<s>', u'fun', u'fact:')
# (u'fun', u'farewel', u'cake')
# (u'key', u'now', u'\U0001f44d')
# ('<s>', u'hankssssssssss', u'u')
# (u"couldn't", u'access', u'on')
# (u'about', u'lion', u'for')
# (u'an', u'excus', u'to')
# (u'year', u'\U0001f389', u'\U0001f388')
# (u'wow', u'i', u'mean')
# ('<s>', u'news', u'matt')
# (u'some', u'adult', u'fun')
# (u'fun', u'-like', u'if')
# (u'time', u'they', u'end')
# (u'indo', u'mutual', u'have')
# (u"you'r", u'not', u'rt')
# (u'hundr', u'of', u'wni')
# (u'betti', u'wright', u'-')
# (u'(rememb', u'me', u'series)')
# (u'even', u'have', u'fun')
# (u'pete', u'preview:', u"don't")
# (u'fun', u'sooo', u'is')
# (u'other', u'new', u'games:')
# (u'some', u'fun', u':)')
# (u'cudd', u'mascot', u'~tackl')
# ('<s>', u'fun', u'time')
# (u'more', u'pre', u'birthday')
# (u'our', u'fan', u'tonit')
# (u'showdown', u'again', u'it')
# (u'i', u"don't", u'care')
# (u'laugh', u'at', u'absolut')
# (u'pavillion', u'to', u'join')
# (u'300', u'like', u'i')
# (u'if', u'ihavetospendaday', u'w/')
# (u'a', u'metal', u'tea')
# (u'you', u'even', u'though')
# (u'everyon', u'last', u'night')
# (u'at', u'world', u'of')
# (u'\U0001f447', u'maichardseizethemo', u'\u2764')
# (u'homi', u'parti', u'were')
# (u'of', u'a', u'white')
# (u'\U0001f3fd', u'\U0001f3b6', u'\u2764')
# (u'real', u'florida', u'would')
# (u'the', u'all', u'the')
# (u'and', u'crazi', u'japanes')
# (u'organ', u'accent', u'travel')
# (u'becaus', u'the', u'clementin')
# ('<s>', u'he', u'real')
# (u'weekend', u'keep', u'those')
# (u'out', u'of', u'thing')
# ('<s>', u'i', u'rememb')
# (u'of', u'the', u'fun')
# (u'to', u'end', u'our')
# (u'proper', u'medic', u'will')
# (u'it', u'last', u'\U0001f60a')
# (u'fun', u'with', u'\U0001f425')
# (u'anoth', u'weekend', u'away')
# (u'share', u'to', u'watch')
# (u'florida', u'spring', u'pollen')
# (u'exclus', u'"st', u'pete')
# (u'photo', u'-', u'friday')
# (u'stop', u'and', u'it')
# (u'to', u'the', u'site')
# (u'it', u'start', u'out')
# (u'bit', u'of', u'doubl')
# (u'got', u'an', u'a-')
# (u'watch', u'it', u'grow')
# (u'my', u'father', u'have')
# (u'behind', u'the', u'scene')
# (u'to', u'third', u'wheel')
# (u'a', u'fun', u'gamei')
# (u'to', u'the', u'darl')
# (u'use', u'of', u'limb')
# (u'the', u'fun', u'start')
# (u'lot', u'better', u'than')
# (u'phone', u'tom;', u'i')
# (u'understand', u'whi', u'teenag')
# (u'a', u'fun', u'idea')
# (u'new', u'organ', u'skincar')
# (u'i', u'could', u'be')
# (u'have', u'happen', u'to')
# ('<s>', u'went', u'straight')
# (u'it', u'a', u'beauti')
# (u'pga', u'locat', u'with')
# (u'make', u'this', u'video')
# (u'to', u'send', u'to')
# (u'fun', u'time', u'in')
# (u'a', u'fun', u'week')
# (u'the', u'discuss', u'that')
# (u'it', u'fun', u'sweati')
# (u'the', u'way', u'you')
# (u'day', u'alarm', u"wasn't")
# (u'but', u"couldn't", u'access')
# (u'they', u'love', u'htt\u2026')
# (u'back', u'into', u'pokemon')
# (u'sun', u'is', u'fun')
# (u'be', u'safe', u'too')
# (u"i'll", u'offer', u'myselflisten')
# (u'tv', u'was', u'alot')
# (u'girl', u'to', u'play')
# (u'when', u'leav', u'jewel')
# (u'on', u'cam', u'now')
# ('<s>', u'hillari', u'clinton')
# (u'how', u'they', u'respond')
# (u'dress', u'will', u'be')
# (u'have', u'too', u'much')
# ('<s>', u'the', u'game')
# (u'i', u'recent', u'discov')
# (u'&amp;', u'laura', u'on')
# (u'possibl', u'silag', u'or')
# (u'in', u'my', u'heart')
# (u'be', u'so', u'much')
# (u'i', u'have', u'some')
# (u'watch', u'the', u'tri')
# (u'liter', u'noth', u'fun')
# (u'gus', u'fri', u'chicken')
# (u'anyon', u'can', u'tri')
# (u'fun', u'play', u'for')
# (u'play', u'so', u'good')
# (u'vinyl', u'too', u'but')
# (u'fun', u'dinner', u'with')
# (u'so', u'there', u'is')
# (u'alway', u'fun', u'to')
# ('<s>', u'wanna', u'do')
# (u'mutual', u'have', u'fun')
# (u'rock', u'and', u'special')
# (u'lil', u'bridg', u'part')
# (u'the', u'tear', u'in')
# (u'game', u'is', u'now')
# (u'who', u'just', u"doesn't")
# (u'i', u'just', u"don't")
# (u'and', u'touch', u'base')
# (u'to', u'hot', u'or')
# (u'podcast', u'are', u'in')
# (u'onc', u'in', u'a')
# (u'fun', u'run', u'as')
# ('<s>', u'had', u'a')
# (u'gooood', u'luck', u'have')
# (u'me', u'series)', u'by')
# ('<s>', u'check', u'out')
# (u'truck', u'as', u'usual')
# ('<s>', u'had', u'so')
# (u'say', u'get', u'taken')
# (u'is', u'onli', u'fun')
# (u'make', u'this', u'shit')
# (u'farewel', u'cake', u'for')
# (u'omg\u3160\u3160\u3160', u'final', u'ohgod')
# (u'game', u'that', u'have')
# (u'episod', u'of', u'\U0001f601')
# (u'your', u'toilet', u'get')
# (u'time', u'he', u'is')
# ('<s>', u'will', u'never')
# (u'kid', u'realli', u'anderp')
# (u'of', u'what', u'happen')
# (u'best', u'fun', u'ever')
# (u'and', u'addict', u'strategi')
# ('<s>', u'get', u'a')
# (u'lion', u'in', u'like')
# (u'fun', u'and', u'adventur')
# (u'a', u'$15', u'gift')
# (u'rt', u'have', u'fun')
# (u'12', u'by', u'12-inch')
# (u'\U0001f31a', u'\U0001f44f', u'\U0001f31a')
# (u'do', u'it', u'to')
# (u'sorri', u'i', u'have')
# (u'like', u'slippi', u'peppi')
# ('<s>', u'too', u'much')
# (u'danc', u'to', u'beyonc\xe9')
# (u'what', u'fun', u'matilda')
# (u'much', u'fun', u'this')
# (u'readi', u'for', u'sunday')
# ('<s>', u'i', u'have')
# (u'in', u'some', u'way')
# (u'to', u'come', u'down')
# (u'up', u'by', u'the')
# (u'was', u'so', u'look')
# (u'-', u'sun', u'3/27')
# (u'and', u'(when', u'your')
# (u'that', u'is', u'for')
# (u'probabl', u'gold', u'rod')
# (u'in', u'your', u'hous')
# (u'fun', u'easter', u'project')
# (u'are', u'you', u'oh')
# ('<s>', u'face', u'of')
# (u'some', u'fun', u'sky')
# (u'trailer', u'\u2014', u'a')
# (u'realiz', u'i', u'was')
# (u'drive', u'the', u'truck')
# (u'fun', u'with', u'my')
# (u'side', u'scroll', u'fun:')
# (u'weekend', u'servic', u'sat')
# (u'need', u'ppl', u'to')
# (u'for', u'had', u'so')
# (u'i', u'work', u'with')
# (u'stay', u'in', u'the')
# (u'awhil', u'ago', u'but')
# (u'probabl', u'after', u'i')
# (u'the', u'other', u'room')
# (u'want', u'to', u'live')
# (u'gonna', u'be', u'stream')
# (u'like', u'she', u'friend')
# (u'as', u'fun', u'as')
# (u"you'r", u'have', u'fun')
# ('<s>', u'it', u'such')
# (u'of', u'holiday', u'feast')
# (u'out', u'watch', u'the')
# (u'so', u'is', u'incred')
# (u'ya', u'realli', u'enjoy')
# (u'suck', u'the', u'fun')
# (u'cotteslo', u'-', u'the')
# (u'my', u'friend', u'are')
# (u'excit', u'news', u'inde')
# (u'aww', u'thank', u'you')
# (u'photo', u'on', u'facebook')
# (u'night', u'\u2026at', u'the')
# (u'grab', u'your', u'sweeti')
# (u'to', u'the', u'parad')
# (u'wish', u'peopl', u'understood')
# (u'let', u'the', u'fun')
# (u'folsom', u'happi', u'associ')
# (u'them', u'this', u'day')
# (u'to', u'be', u'amaz')
# (u'be', u'that', u'bad')
# ('<s>', u'move', u'is')
# (u'more', u'fun', u'x')
# (u'studio', u'whos', u'\u2026')
# (u'incred', u'badass', u"didn't")
# (u'fun', u'night', u'with')
# (u'do', u'you', u'have')
# (u'much', u'about', u'lookin')
# (u'in', u'the', u'spirit')
# (u'\U0001f611', u'\U0001f611', u'\U0001f611')
# (u'were', u'so', u'damn')
# (u'will', u'happen', u'here')
# (u'fun', u'jeffrey', u'nathanson')
# (u"we'd", u'all', u'have')
# ('<s>', u'have', u'some')
# (u'sort', u'you', u'out')
# (u'on', u'amazon', u'enter')
# (u'someth', u'whi', u'is')
# (u'cream', u'cool', u'we')
# (u'friday', u'what', u'fun')
# (u'fun', u'\U0001f62d', u'\U0001f62d')
# (u'us', u'to', u'kick')
# ('<s>', u'teacher', u'help')
# (u'food', u'and', u'fun')
# (u'have', u'you', u'in')
# (u'weekend', u'\U0001f613', u'\U0001f613')
# (u'today', u'no', u'live')
# ('<s>', u'here', u'a')
# (u'and', u"you'r", u'make')
# (u'has', u'some', u'of')
# (u'tobe', u'toe', u'fluff')
# (u'itali', u'around:', u'itali')
# (u'onli', u'3', u'game')
# (u'was', u'fun', u'until')
# ('<s>', u'even', u'my')
# ('<s>', u'his', u'is')
# (u'fun', u'crew', u'ht\u2026')
# (u'recip', u'thank', u'to')
# (u'pretti', u'\u2600', u'\ufe0f')
# (u'quarter', u'4th', u'quarter')
# (u'w/@gwynethpaltrow', u'learn', u'about')
# (u'photoshoot', u'are', u'fun')
# (u'be', u'fun', u"i'm")
# ('<s>', u'that', u'sound')
# (u'look', u'like', u'fun')
# (u'11am', u'fun', u'stuff')
# (u'go', u'through', u'with')
# (u'a', u'fun', u'sexi')
# (u'of', u'your', u'couch')
# (u'believ', u'it', u'been')
# (u'fun', u'ratchet', u'girl/')
# (u'are', u'in', u'life')
# (u'a', u'clip', u'from')
# (u'to', u'18', u'becaus')
# (u'maichardseizethemo', u'\u2764', u'\u2764')
# (u'more', u'fun', u'h\u2026')
# (u'ppl', u'magic', u'know')
# (u'-', u'his', u'antic')
# (u'scratter', u'babe', u'xx')
# (u'that', u'way', u'unless')
# (u'updat', u'nalang', u'sa')
# (u'come', u'outta', u'nowher')
# (u'it', u'make', u'that')
# ('<s>', u'"@eugeneadu:', u'follow')
# (u'\U0001f44c', u'\U0001f3fd', u'\U0001f497')
# (u'miss', u'play', u'for')
# (u'book', u'awesom', u'art')
# (u'like', u'to', u'suck')
# (u'to', u'guessup', u'download')
# (u'a', u'fun', u'game')
# (u'*make', u'a', u'typo*')
# (u'if', u'you', u'leav')
# (u'that', u'\U0001f595', u'\U0001f3ff')
# (u'want', u'to', u'do')
# (u'it', u'not', u'green')
# (u'fun', u'fact:', u'the')
# (u'it', u'grow', u'and')
# (u'rest', u'hope', u'u')
# (u'-', u'take', u'with')
# (u'to', u'me', u'onlin')
# (u'support', u'all', u'season')
# (u'in', u'over', u'half')
# (u'boy', u'readi', u'for')
# (u'that', u'would', u'be')
# (u'watch', u'everyon', u'snapchat')
# (u'my', u'phone', u'and')
# (u'the', u'fl', u'key')
# ('<s>', u'my', u'shift')
# ('<s>', u'a', u'helluva')
# (u'i', u'rememb', u'run')
# ('<s>', u'sculptur', u'by')
# (u'fun', u'pictur', u'in')
# ('<s>', u'we', u'were')
# (u'a', u'box', u'full')
# (u'in', u'vega', u'for')
# (u'time', u'to', u'step')
# (u'yeah', u'&amp;', u'too:)')
# (u'trump', u'hair', u'to')
# ('<s>', u'tonight', u'we')
# (u'i', u'want', u'to')
# (u'longer', u'fun', u'now')
# (u"we'll", u'talk', u'adult')
# (u'thank', u'you', u'charlott')
# (u'happen', u'to', u'a')
# (u'have', u'fun', u'for')
# (u'fun', u'now', u'just')
# (u'barf', u'into', u'a')
# (u'color', u'corrector', u'sephora')
# (u'and', u'excit', u'while')
# (u'page', u'\U0001f3a4', u'\U0001f48b')
# (u'ident', u'clash', u'royal')
# (u'it', u'\U0001f602', u'\U0001f60b')
# (u'great', u'night', u'bartendinglol')
# (u'it', u'sound', u'\U0001f61d')
# (u'best', u'respons', u';)')
# (u'to', u'watch', u'love')
# (u'to', u'be', u'rude')
# (u'to', u'emot', u'is')
# (u'get', u'off', u'unless')
# (u'it', u'fun', u'\U0001f62d')
# (u'wallet', u'\U0001f349', u'|')
# (u'again', u'record', u'it')
# (u'from', u'zootopia', u'to')
# (u'i', u'repli', u'back')
# (u'"to', u'love', u'me')
# (u'sure', u'sound', u'fun')
# (u'show', u'love', u'4')
# (u'harder', u'to', u'choos')
# ('<s>', u"i'm", u'still')
# (u'and', u'i', u'accident')
# (u'mom', u'will', u'be')
# (u'may', u'but', u'mayb')
# (u'str8', u'yass', u'\U0001f602')
# (u'funi', u'got', u'to')
# (u'between', u'the', u'cushion')
# (u'the', u'intro', u'to')
# (u'whenev', u"i'm", u'alon')
# ('<s>', u'mani', u'peopl')
# (u'some', u'fun', u'in')
# (u"i'm", u'still', u'in')
# (u'by', u'the', u'sea')
# (u'i', u'enjoy', u'this')
# (u'video', u'from', u'help')
# (u'game', u'until', u'your')
# (u'are', u'in', u'your')
# (u'the', u'idol', u'and')
# (u'fun-tim', u'world"', u'extend')
# (u'newli', u'releas', u'vinyl')
# ('<s>', u'want', u'to')
# (u'scrrame', u'i', u'cant')
# (u'who', u'use', u'ipad')
# (u'400+', u'rev', u'h\u2026')
# (u'you', u'\u2764', u'\ufe0f')
# (u'seen', u'that', u"must'v")
# (u'to', u'refresh', u'my')
# (u'fool', u'after', u'scho\u2026')
# (u'start', u'out', u'but')
# (u'3/27', u'9', u'&amp;')
# (u'all', u'love', u'pleas')
# (u'but', u"i'v", u'heard')
# (u'load', u'of', u'fun')
# (u'have', u'fun', u'this')
# (u'fun', u"y'all", u'be')
# (u'watch', u'the', u'mass')
# (u'a', u'connect', u'for')
# (u'fun', u'new', u'peopl')
# (u'if', u'i', u'can')
# (u'today', u'with', u'dalek')
# (u'kitchen', u'cabinet', u'with')
# (u'play', u'with', u'in')
# (u'love', u'you', u'can')
# (u'friday', u'fun', u'quiz')
# (u'heard', u'so', u'much')
# (u'car', u'parade;', u'gonna')
# (u'this', u'real', u'cool')
# (u'30', u'million', u'lawyer')
# (u'sun', u'which', u'i')
# (u'hell', u'i', u'wish')
# (u'atlant', u'citi', u'fun')
# (u'nate', u'\U0001f64c', u'\U0001f3fb')
# (u'on', u'my', u'first')
# (u'yet', u'someth', u'in')
# (u'1000s', u'of', u'who')
# (u'contact', u'me', u'for')
# (u'visit', u'onc', u'a')
# (u'gotta', u'have', u'so')
# (u'so', u'fun', u'all')
# (u'interact', u'game', u'book')
# (u'we', u'all', u'know')
# (u'has', u'a', u'group')
# (u'they', u'suck', u'at')
# (u'fun', u'and', u'crazi')
# (u'seri', u'with', u'the')
# (u'fun', u'than', u'senior')
# (u'help', u'put', u'on')
# (u'clean', u'fast-pac', u'i')
# (u'onli', u'22', u'the')
# (u'bummer', u'alway', u'fun')
# (u'pretti', u'i', u'have')
# (u'a', u'fade', u'knife')
# ('<s>', u'what', u'a')
# (u"i'm", u'come', u'to')
# (u'at', u'cpac', u'is')
# (u'be', u'kind', u'to')
# (u'sesam', u'street', u'paid')
# (u'out', u'of', u'context-us')
# (u'troubl', u'have', u'fun')
# (u'when', u'someon', u'text')
# (u'fun', u'to', u'look')
# (u'\U0001f60d', u'check', u'out')
# (u'preview:', u"don't", u'repeat"')
# (u'\ufe0f', u'\U0001f60e', u'\U0001f41f')
# (u'to', u'watch', u'not')
# (u'bro', u'show', u'out')
# (u'fun', u'rawdograw', u'teflontwuan')
# (u'you', u'unblock', u'me')
# (u'kiss', u'ars', u'an')
# (u'a', u'great', u'time')
# ('<s>', u'rec', u'moba')
# (u'a', u'fun', u'languag')
# ('<s>', u'oday', u'is')
# ('<s>', u'pretti', u'sure')
# (u"don't", u'have', u'to')
# ('<s>', u'show', u'up')
# (u'antic', u'&amp;', u'view')
# ('<s>', u'my', u'confid')
# (u'one', u'girl', u'stalk')
# (u'blue', u'plus', u'18')
# (u'lunch', u"wasn't", u'a')
# (u'while', u'get', u'thing')
# (u'it', u'more', u'fun')
# (u'out', u'with', u'famili')
# (u'the', u'beach', u'for')
# (u'fun', u'at', u'mariposa')
# (u'me', u'and', u'vj')
# (u'so', u'so', u'so')
# (u'new', u'book--which', u"isn't")
# (u'okkinderhook', u'(@okkinderhook):', u'super')
# ('<s>', u'lol', u'twitter')
# (u'up', u'with', u'this')
# (u'is', u'my', u'3rd')
# (u'our', u'australian', u'friend')
# (u'take', u'me', u'30')
# (u'fun', u"can't", u'wait')
# (u'go', u'viral', u'oh')
# (u'to', u'play', u'tell')
# (u"i'm", u'suppos', u'to')
# (u'be', u'good', u'practic')
# (u'of', u'cours', u'ion')
# ('<s>', u'school', u'spirit')
# (u'the', u'scene', u'of')
# (u'my', u'grandma', u'and')
# (u'today', u"i'm", u'have')
# (u'got', u'to', u'hangout')
# (u'fun', u'steam', u'game')
# (u'fun', u'when', u'go')
# (u'now', u'you', u'unblock')
# (u'you', u'at', u'home')
# (u'too', u'much', u'for')
# (u'the', u'anim', u'shelter')
# (u'\U0001f600', u'\U0001f600', u'fun')
# (u'lead', u'a', u'differ')
# (u'ya', u'i', u'had')
# (u'treat', u'the', u'same')
# (u'be', u'fun', u'come')
# (u'4', u'=', u'longest')
# (u'\U0001f409', u'\U0001f432', u'\U0001f525')
# (u'start', u'now', u'forza')
# ('<s>', u'some', u'random')
# (u'so', u'fun', u'make')
# (u'\U0001f602', u'\U0001f602', u'\U0001f602')
# (u'sam', u'goody/fy', u'et/c')
# (u'you', u'two', u'have')
# (u'all', u'her', u'damn')
# (u'cam', u'now', u'more')
# (u'sculptur', u'by', u'the')
# (u'choral', u'acadienn', u'singer')
# (u'to', u'use', u'the')
# (u'again', u'and', u'you')
# (u'time', u'\U0001f44d', u'\U0001f609')
# (u'get', u'those', u'time')
# (u'fight', u'breakdown/dick', u'talk')
# (u'and', u'visitor', u'pose')
# (u'relay', u'quit', u'fun')
# (u'get', u'into', u'for')
# (u'each', u'day', u'3pm')
# ('<s>', u'also', u'i')
# (u'i', u'ran', u'a')
# (u'down', u'for', u'craft')
# ('<s>', u'lol', u'now')
# (u'have', u'fun', u'suck')
# (u'see', u'them', u'but')
# (u'for', u'posh', u'fun')
# (u'hockey', u'team', u'are')
# (u'someth', u'to', u'send')
# (u'are', u'pack', u'w/')

# %%
def predict(strings):
    
    token = emoji_preprocess(strings, True)
    
    alpha1 ,alpha2, alpha3 = (1/3, 1/3, 1/3)
    
    if token[-1:][0] in bigram_dict:

    if tuple(token[-2:]) in trigram_dict:

    if tuple(token[-3:]) in quadgram_dict:
# Out:
#   File "<ipython-input-158-e1608a61e2ba>", line 11
#     if tuple(token[-3:]) in quadgram_dict:
#      ^
# IndentationError: expected an indented block

# %%
proc_str = emoji_preprocess('are you', predict=True)

# %%
if tuple(proc_str[-2:]) in trigram_dict:
    print trigram_dict[tuple(proc_str[-2:])]
# Out:
# Counter({u'guy': 0.5, u'oh': 0.5})

# %%
quadgram_dict[tuple(proc_str[-3:])].most_common()
# Out:
# []

# %%
total = bigram_dict[proc_str[-1:][0]] + quadgram_dict[tuple(proc_str[-3:])] + trigram_dict[tuple(proc_str[-2:])]

# %%
if tuple(proc_str[-3:]) in quadgram_dict:
    xx =  quadgram_dict[tuple(proc_str[-3:])].most_common()

# %%
if proc_str[-1:][0] in bigram_dict:
    yy = trigram_dict[tuple(proc_str[-1:][0])]

# %%
zz = defaultdict(Counter)

# %%
zz['test']['tt']= 3
zz['test']['xx']= 1

# %%
zz['tests'].most_common()
# Out:
# []

# %% [markdown]
# # Count num tweets

# %%
sc.textFile('/home/han/Documents/Github/emoji_predictor/data/twitter_dump.txt').filter(lambda x: len(x)>1 and 'created_at' in x).count()
# Out:
# 730980

# %%
REGEX
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-a0f640b8da34> in <module>()
# ----> 1 REGEX
#
# NameError: name 'REGEX' is not defined

# %%
from textblob import TextBlob

# %% [markdown]
# # Testing word2vec

# %%
with open('/home/han/.api_key/awsaccesskey.json') as f:
    key= json.load(f)
    
    access= key['access-key']
    secret = key['secret-access-key']

# %%
data = sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/tweet/*/*/*.bz2')

# %%
from pyspark.mllib.feature import Word2Vec
word2vec = Word2Vec()

# %%
w2v = word2vec.fit(tweets_tokens)

# %%
print w2v.findSynonyms('you',10)[5][0]
# Out:
# 💖

# %%
print u'\U0001f1fd'
# Out:
# 🇽

# %% [markdown]
# # Big Tweets

# %%
with open('/home/han/.api_key/awsaccesskey.json') as f:
    key= json.load(f)
    
    access= key['access-key']
    secret = key['secret-access-key']

# %%
data1= sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/tweets/01/00/04.json.bz2')
data2= sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/tweets/01/00/06.json.bz2')
data3= sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/tweets/01/00/05.json.bz2')
data4= sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/tweets/01/00/07.json.bz2')

data = data1.union(data3)

# %%
big_tweet = data.union(data2).filter(lambda tw: len(tw)>1)\
.filter(lambda tw: 'created_at' in tw)\
.map(tweet_process)\
.filter(lambda tw: tw != None)\
.map(lambda tw: tw['text'].lower() )\
.map(emoji_preprocess)

# %%
data = data.union(data3)

# %%
data.count()
# Out:
# 45

# %%
data.union(data2).count()
# Out:
# 322

# %%
d.count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-83-fad350352fac> in <module>()
# ----> 1 d.count()
#
# /usr/local/spark/python/pyspark/rdd.pyc in count(self)
#    1002         3
#    1003         """
# -> 1004         return self.mapPartitions(lambda i: [sum(1 for _ in i)]).sum()
#    1005
#    1006     def stats(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in sum(self)
#     993         6.0
#     994         """
# --> 995         return self.mapPartitions(lambda x: [sum(x)]).fold(0, operator.add)
#     996
#     997     def count(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in fold(self, zeroValue, op)
#     867         # zeroValue provided to each partition is unique from the one provided
#     868         # to the final reduce call
# --> 869         vals = self.mapPartitions(func).collect()
#     870         return reduce(op, vals, zeroValue)
#     871
#
# /usr/local/spark/python/pyspark/rdd.pyc in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/java_gateway.pyc in __call__(self, *args)
#     833         answer = self.gateway_client.send_command(command)
#     834         return_value = get_return_value(
# --> 835             answer, self.gateway_client, self.target_id, self.name)
#     836
#     837         for temp_arg in temp_args:
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/protocol.pyc in get_return_value(answer, gateway_client, target_id, name)
#     308                 raise Py4JJavaError(
#     309                     "An error occurred while calling {0}{1}{2}.\n".
# --> 310                     format(target_id, ".", name), value)
#     311             else:
#     312                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.hadoop.fs.s3.S3Exception: org.jets3t.service.S3ServiceException: S3 GET failed for '/' XML Error Message: <?xml version="1.0" encoding="UTF-8"?><Error><Code>NoSuchBucket</Code><Message>The specified bucket does not exist</Message><BucketName>han.tweets</BucketName><RequestId>E97A99B853C5EFD2</RequestId><HostId>fk7+Jj/8BLNwE4aPBBq/9sxwA0gsizXszhpDVHP7TNkOnVg/3mGWdFn/l0B2treBU3VhH1zu9Cw=</HostId></Error>
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.handleServiceException(Jets3tNativeFileSystemStore.java:229)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:169)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:146)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:140)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invokeMethod(RetryInvocationHandler.java:85)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invoke(RetryInvocationHandler.java:62)
# 	at org.apache.hadoop.fs.s3native.$Proxy13.list(Unknown Source)
# 	at org.apache.hadoop.fs.s3native.NativeS3FileSystem.getFileStatus(NativeS3FileSystem.java:376)
# 	at org.apache.hadoop.fs.FileSystem.getFileStatus(FileSystem.java:1397)
# 	at org.apache.hadoop.fs.FileSystem.globStatusInternal(FileSystem.java:1066)
# 	at org.apache.hadoop.fs.FileSystem.globStatus(FileSystem.java:1007)
# 	at org.apache.hadoop.mapred.FileInputFormat.listStatus(FileInputFormat.java:177)
# 	at org.apache.hadoop.mapred.FileInputFormat.getSplits(FileInputFormat.java:208)
# 	at org.apache.spark.rdd.HadoopRDD.getPartitions(HadoopRDD.scala:199)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.rdd.MapPartitionsRDD.getPartitions(MapPartitionsRDD.scala:35)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.api.python.PythonRDD.getPartitions(PythonRDD.scala:58)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1929)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:927)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:150)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:111)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:316)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:926)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:405)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.jets3t.service.S3ServiceException: S3 GET failed for '/' XML Error Message: <?xml version="1.0" encoding="UTF-8"?><Error><Code>NoSuchBucket</Code><Message>The specified bucket does not exist</Message><BucketName>han.tweets</BucketName><RequestId>E97A99B853C5EFD2</RequestId><HostId>fk7+Jj/8BLNwE4aPBBq/9sxwA0gsizXszhpDVHP7TNkOnVg/3mGWdFn/l0B2treBU3VhH1zu9Cw=</HostId></Error>
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.performRequest(RestS3Service.java:416)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.performRestGet(RestS3Service.java:752)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.listObjectsInternal(RestS3Service.java:1117)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.listObjectsChunkedImpl(RestS3Service.java:1087)
# 	at org.jets3t.service.S3Service.listObjectsChunked(S3Service.java:1488)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:156)
# 	... 49 more

# %%
sc.textFile('s3n://AKIAJAARWQ57D4HCBHRQ:7xdG1e4BPcEmX4EfyGIjMiSJjxyKvnSXnWGYNALm@han.tweets/01/00/05.json.bz2').count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-90-20bfef7d986a> in <module>()
# ----> 1 sc.textFile('s3n://AKIAJAARWQ57D4HCBHRQ:7xdG1e4BPcEmX4EfyGIjMiSJjxyKvnSXnWGYNALm@han.tweets/01/00/05.json.bz2').count()
#
# /usr/local/spark/python/pyspark/rdd.pyc in count(self)
#    1002         3
#    1003         """
# -> 1004         return self.mapPartitions(lambda i: [sum(1 for _ in i)]).sum()
#    1005
#    1006     def stats(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in sum(self)
#     993         6.0
#     994         """
# --> 995         return self.mapPartitions(lambda x: [sum(x)]).fold(0, operator.add)
#     996
#     997     def count(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in fold(self, zeroValue, op)
#     867         # zeroValue provided to each partition is unique from the one provided
#     868         # to the final reduce call
# --> 869         vals = self.mapPartitions(func).collect()
#     870         return reduce(op, vals, zeroValue)
#     871
#
# /usr/local/spark/python/pyspark/rdd.pyc in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/java_gateway.pyc in __call__(self, *args)
#     833         answer = self.gateway_client.send_command(command)
#     834         return_value = get_return_value(
# --> 835             answer, self.gateway_client, self.target_id, self.name)
#     836
#     837         for temp_arg in temp_args:
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/protocol.pyc in get_return_value(answer, gateway_client, target_id, name)
#     308                 raise Py4JJavaError(
#     309                     "An error occurred while calling {0}{1}{2}.\n".
# --> 310                     format(target_id, ".", name), value)
#     311             else:
#     312                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.hadoop.fs.s3.S3Exception: org.jets3t.service.S3ServiceException: S3 GET failed for '/' XML Error Message: <?xml version="1.0" encoding="UTF-8"?><Error><Code>NoSuchBucket</Code><Message>The specified bucket does not exist</Message><BucketName>han.tweets</BucketName><RequestId>DA67AF39FB7ACB8E</RequestId><HostId>mK+8ejxC4YJJKGvnDe22Oz/rrfjPSE0Q0hqekrNS0GfOnkpxPDz+Pxo8LMH9henQtewAF2LfGHc=</HostId></Error>
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.handleServiceException(Jets3tNativeFileSystemStore.java:229)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:169)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:146)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:140)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invokeMethod(RetryInvocationHandler.java:85)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invoke(RetryInvocationHandler.java:62)
# 	at org.apache.hadoop.fs.s3native.$Proxy13.list(Unknown Source)
# 	at org.apache.hadoop.fs.s3native.NativeS3FileSystem.getFileStatus(NativeS3FileSystem.java:376)
# 	at org.apache.hadoop.fs.FileSystem.getFileStatus(FileSystem.java:1397)
# 	at org.apache.hadoop.fs.FileSystem.globStatusInternal(FileSystem.java:1066)
# 	at org.apache.hadoop.fs.FileSystem.globStatus(FileSystem.java:1007)
# 	at org.apache.hadoop.mapred.FileInputFormat.listStatus(FileInputFormat.java:177)
# 	at org.apache.hadoop.mapred.FileInputFormat.getSplits(FileInputFormat.java:208)
# 	at org.apache.spark.rdd.HadoopRDD.getPartitions(HadoopRDD.scala:199)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.rdd.MapPartitionsRDD.getPartitions(MapPartitionsRDD.scala:35)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.api.python.PythonRDD.getPartitions(PythonRDD.scala:58)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1929)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:927)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:150)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:111)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:316)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:926)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:405)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.GeneratedMethodAccessor49.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.jets3t.service.S3ServiceException: S3 GET failed for '/' XML Error Message: <?xml version="1.0" encoding="UTF-8"?><Error><Code>NoSuchBucket</Code><Message>The specified bucket does not exist</Message><BucketName>han.tweets</BucketName><RequestId>DA67AF39FB7ACB8E</RequestId><HostId>mK+8ejxC4YJJKGvnDe22Oz/rrfjPSE0Q0hqekrNS0GfOnkpxPDz+Pxo8LMH9henQtewAF2LfGHc=</HostId></Error>
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.performRequest(RestS3Service.java:416)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.performRestGet(RestS3Service.java:752)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.listObjectsInternal(RestS3Service.java:1117)
# 	at org.jets3t.service.impl.rest.httpclient.RestS3Service.listObjectsChunkedImpl(RestS3Service.java:1087)
# 	at org.jets3t.service.S3Service.listObjectsChunked(S3Service.java:1488)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.list(Jets3tNativeFileSystemStore.java:156)
# 	... 48 more

# %%
import ssl
import boto
if hasattr(ssl, '_create_unverified_context'):
   ssl._create_default_https_context = ssl._create_unverified_context
conn = boto.connect_s3()
b = conn.get_bucket('han.tweets.bucket')
for i, key in enumerate(b.get_all_keys()):
    print i ,'s3n://'+access+':'+secret +'@han.'+key.name
    if i ==0:
        data = sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/'+key.name)
    if i == 20:
        break
    else:
        temp_data = sc.textFile('s3n://'+access+':'+secret +'@han.'+key.name)
        data = data.union(data)
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2cf7a4bc8aa> in <module>()
#       6 b = conn.get_bucket('han.tweets.bucket')
#       7 for i, key in enumerate(b.get_all_keys()):
# ----> 8     print i ,'s3n://'+access+':'+secret +'@han.'+key.name
#       9     if i ==0:
#      10         data = sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/'+key.name)
#
# NameError: name 'access' is not defined

# %%
data.count()
# Out:
# 9664

# %%
zz = b.get_all_keys()

# %%
tweets =  data\
.filter(lambda tw: len(tw)>1)\
.filter(lambda tw: 'created_at' in tw)\
.map(tweet_process)\
.filter(lambda tw: tw != None)\
.map(lambda tw: tw['text'].lower() )\
.count()

# %%
tweets
# Out:
# 3584

# %%
run tweet_parse.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/han/Documents/Github/emoji_predictor/tweet_parse.py in <module>()
#     286     # sc = SparkContext()
#     287     # data = get_data(sc)
# --> 288     data = sc.textFile('data/twitter_dump.txt')
#     289     WP = WordPredictor()
#     290     WP.fit(data)
#
# NameError: name 'sc' is not defined

# %%
data = sc.textFile('data/twitter_dump.txt')

# %%
from tweet_parse import *

# %%
import pandas as pd
def emoji_list():
    df_emoji = pd.read_csv('data/emoji_table.txt', encoding='utf-8', index_col=0)
    df_emoji['count']=0
    emoji_dict = df_emoji['count'].to_dict()

    df_div_emoji = pd.read_csv('data/diversity_table.txt', encoding='utf-8', index_col=0)
    df_div_emoji['count'] = 0
    div_emoji_keys = df_div_emoji['count'].to_dict().keys()
    human_emoji = list(set([ list(emoji)[0] for emoji in div_emoji_keys]))

    return emoji_dict.keys()+human_emoji

# %%
class WordPredictor(object):

    def __init__(self):
        # set up stemming agent
        self.snowball = SnowballStemmer('english')
        # list of emoji
        self.emoji_list = emoji_list()

        # REGEX for finding emoji
        self.REGEX = u"[\U00002712\U00002714\U00002716\U0000271d\U00002721\U00002728\U00002733\U00002734\U00002744\U00002747\U0000274c\U0000274e\U00002753-\U00002755\U00002757\U00002763\U00002764\U00002795-\U00002797\U000027a1\U000027b0\U000027bf\U00002934\U00002935\U00002b05-\U00002b07\U00002b1b\U00002b1c\U00002b50\U00002b55\U00003030\U0000303d\U0001f004\U0001f0cf\U0001f170\U0001f171\U0001f17e\U0001f17f\U0001f18e\U0001f191-\U0001f19a\U0001f201\U0001f202\U0001f21a\U0001f22f\U0001f232-\U0001f23a\U0001f250\U0001f251\U0001f300-\U0001f321\U0001f324-\U0001f393\U0001f396\U0001f397\U0001f399-\U0001f39b\U0001f39e-\U0001f3f0\U0001f3f3-\U0001f3f5\U0001f3f7-\U0001f4fd\U0001f4ff-\U0001f53d\U0001f549-\U0001f54e\U0001f550-\U0001f567\U0001f56f\U0001f570\U0001f573-\U0001f579\U0001f587\U0001f58a-\U0001f58d\U0001f590\U0001f595\U0001f596\U0001f5a5\U0001f5a8\U0001f5b1\U0001f5b2\U0001f5bc\U0001f5c2-\U0001f5c4\U0001f5d1-\U0001f5d3\U0001f5dc-\U0001f5de\U0001f5e1\U0001f5e3\U0001f5ef\U0001f5f3\U0001f5fa-\U0001f64f\U0001f680-\U0001f6c5\U0001f6cb-\U0001f6d0\U0001f6e0-\U0001f6e5\U0001f6e9\U0001f6eb\U0001f6ec\U0001f6f0\U
001f1e8\U0001f1ee\U0001f1f0\U0001f1f7-\U0001f1fb\U0001f1fe]|\U0001f1f2[\U0001f1e6\U0001f1e8-\U0001f1ed\U0001f1f0-\U0001f1ff]|\U0001f1f3[\U0001f1e6\U0001f1e8\U0001f1ea-\U0001f1ec\U0001f1ee\U0001f1f1\U0001f1f4\U0001f1f5\U0001f1f7\U0001f1fa\U0001f1ff]|\U0001f1f4\U0001f1f2|\U0001f1f5[\U0001f1e6\U0001f1ea-\U0001f1ed\U0001f1f0-\U0001f1f3\U0001f1f7-\U0001f1f9\U0001f1fc\U0001f1fe]|\U0001f1f6\U0001f1e6|\U0001f1f7[\U0001f1ea\U0001f1f4\U0001f1f8\U0001f1fa\U0001f1fc]|\U0001f1f8[\U0001f1e6-\U0001f1ea\U0001f1ec-\U0001f1f4\U0001f1f7-\U0001f1f9\U0001f1fb\U0001f1fd-\U0001f1ff]|\U0001f1f9[\U0001f1e6\U0001f1e8\U0001f1e9\U0001f1eb-\U0001f1ed\U0001f1ef-\U0001f1f4\U0001f1f7\U0001f1f9\U0001f1fb\U0001f1fc\U0001f1ff]|\U0001f1fa[\U0001f1e6\U0001f1ec\U0001f1f2\U0001f1f8\U0001f1fe\U0001f1ff]|\U0001f1fb[\U0001f1e6\U0001f1e8\U0001f1ea\U0001f1ec\U0001f1ee\U0001f1f3\U0001f1fa]|\U0001f1fc[\U0001f1eb\U0001f1f8]|\U0001f1fd\U0001f1f0|\U0001f1fe[\U0001f1ea\U0001f1f9]|\U0001f1ff[\U0001f1e6\U0001f1f2\U0001f1fc]|[0-9*#]\ufe0f\u20e3"

    def _tweet_process(self, tweet):
        KEY = 'text'
        try:
            tw = json.loads(tweet.strip())
            if KEY not in tw or tw['lang']!= 'en':
                return None
            return tw

        except Exception as e:
            return None



    def _emoji_preprocess(self, tweet, predict=False):
        # add space before and after space
        for emoji in re.findall(self.REGEX, tweet):
            tweet = tweet.replace(emoji, ' ' + emoji + ' ')

        # tokenize and remove rt and @ and https://
        tweet = re.sub('\?', '', tweet)
        tweet = re.sub('\.', '', tweet)
        tweet = re.sub(',', '', tweet)
        tweet = re.sub('!', '', tweet)

        tweet_tmp = [ self.snowball.stem(wd) for wd in tweet.strip('rt').split() \
        if not wd.startswith('@') and not wd.startswith('http') and not wd.startswith('#') ]

        if predict:
            tweet_token = ['<s>'] + tweet_tmp
        else:
            tweet_token = ['<s>'] + tweet_tmp #+ ['</s>']

        return tweet_token

    def _bigrams(self, tweet):
        # generate bigrams from tweets
        return list(nltk.bigrams(tweet))

    def _trigrams(self, tweet):
        # generate trigrams from tweets
        return [((w1, w2), w3) for w1, w2, w3 in nltk.trigrams(tweet)]

    def _quadgrams(self, tweet):
        #generate n grams
        return [((w1, w2, w3), w4) for w1, w2, w3, w4 in nltk.ngrams(tweet, 4)]



    def fit(self, data, w_bi=1./6, w_tri=1./3, w_quad=1./2):
        """
        data: sc.textFile() object
        TODO:  save bigram, trigram, quagram dict to pickle

        """
        # set weight for n_gram models, they should add up to one
        self.w_bi = w_bi
        self.w_tri = w_tri
        self.w_quad = w_quad

        tweets =  data\
        .filter(lambda tw: len(tw)>1)\
        .filter(lambda tw: 'created_at' in tw)\
        .map(self._tweet_process)\
        .filter(lambda tw: tw != None)\
        .map(lambda tw: tw['text'].lower() )\
        .map(self._emoji_preprocess)

        tweets.cache()

        bigram_count = tweets\
                        .flatMap(self._bigrams).map(lambda bg: (bg, 1))\
                        .reduceByKey(lambda cnt1, cnt2: cnt1+cnt2)\
                        .collect()
        trigram_count = tweets\
                        .flatMap(self._trigrams).map(lambda bg: (bg, 1))\
                        .reduceByKey(lambda cnt1, cnt2: cnt1+cnt2)\
                        .collect()
        quadgrams_count = tweets\
                        .flatMap(self._quadgrams).map(lambda bg: (bg, 1))\
                        .reduceByKey(lambda cnt1, cnt2: cnt1+cnt2)\
                        .collect()


        self.bigram_dict = defaultdict(Counter)
        self.trigram_dict = defaultdict(Counter)
        self.quadgram_dict= defaultdict(Counter)

        for ((w0, w1) , cnt) in bigram_count:
            self.bigram_dict[w0][w1] = cnt

        for (((w0, w1), w2), cnt) in trigram_count:
            self.trigram_dict[(w0, w1)][w2] = cnt

        for (((w0, w1, w2), w3), cnt) in quadgrams_count:
            self.quadgram_dict[(w0, w1, w2)][w3] = cnt

        # normalizing the Counter
        for key in self.bigram_dict:
            total = sum(self.bigram_dict[key].values())
            for val in self.bigram_dict[key]:
                self.bigram_dict[key][val] = self.bigram_dict[key][val]/float(total)

        for key in self.trigram_dict:
            total = sum(self.trigram_dict[key].values())
            for val in self.trigram_dict[key]:
                self.trigram_dict[key][val] = self.trigram_dict[key][val]/float(total)


        for key in self.quadgram_dict:
            total = sum(self.quadgram_dict[key].values())
            for val in self.quadgram_dict[key]:
                self.quadgram_dict[key][val] = self.quadgram_dict[key][val]/float(total)


        self.tweets = tweets
        self._build_w2v()


    def _weighted_ngram(self, key, model, wt):
        """
        redistribute probability by weight
        """
        copy_mod = model[key].copy()

        for gram in copy_mod:
            copy_mod[gram] = copy_mod[gram]*wt
        return copy_mod


    def _backoff_model(self, proc_str):
        bigram_mod = self._weighted_ngram(proc_str[-1:][0], self.bigram_dict, self.w_bi)
        trigram_mod = self._weighted_ngram(tuple(proc_str[-2:]), self.trigram_dict, self.w_tri)
        quadgram_mod = self._weighted_ngram(tuple(proc_str[-3:]), self.quadgram_dict, self.w_quad)
        return bigram_mod + trigram_mod + quadgram_mod

    def predict(self, string):
        """
        Perform model prediction
        string: raw string input
        w_bi, w_tri, w_quad: weights for bigram, triagram and quadgram model,
                            should add up to one
        """
        # preprocess the string as you preprocess tweets
        proc_str = self._emoji_preprocess(string, predict=True)
        stupid_backoff = self._backoff_model(proc_str)

        if len(stupid_backoff) != 0 and stupid_backoff != '<s>':
            output = self._word_to_emoji(stupid_backoff.most_common()[0][0])
            print output
            return  output, zip(*stupid_backoff.most_common())[0][:5]
        else:
            print 'not found', u'\U0001f600'
            return u'\U0001f600'


    def _word_to_emoji(self, wd):
        try:
            for w, score in self.w2v.findSynonyms(wd, 99999): # 99999 for everything
                if w in self.emoji_list:
                    return w
            print 'nothing found'
            return u'\U0001f600'
        except:
            print 'exception error'
            return u'\U0001f600'


    def _build_w2v(self):
        word2vec = Word2Vec()
        self.w2v = word2vec.fit(self.tweets)



    def _score(self, string):
        """
        calculate the perplexity score for a single string
        """
        proc_str = self._emoji_preprocess(string)

        perplexity = 1.0

        if len(proc_str) > 4 :
            n = 4
        else:
            n = len(proc_str)

        k = 0
        for seg in nltk.ngrams(proc_str, n):
            k += 1
            if n == 4:
                quad = seg[:3]
                tri = seg[1:3]
                bi = seg[2:3][0]
            elif n == 3:
                quad = seg[:3]
                tri = seg[:2]
                bi = seg[1:2][0]
            elif n == 2:
                quad = seg[:3]
                tri = seg[:2]
                bi = seg[0]

            pred = seg[-1]

            perplexity *= (self.w_quad * self.quadgram_dict[quad][pred]\
                            + self.w_tri * self.trigram_dict[tri][pred]\
                                + self.w_bi * self.bigram_dict[bi][pred])


        return np.power(perplexity, 1./k)


    def perplexity_score(self, data):

        tweets =  data\
                .filter(lambda tw: len(tw)>1)\
                .filter(lambda tw: 'created_at' in tw)\
                .map(self._tweet_process)\
                .filter(lambda tw: tw != None)\
                .map(lambda tw: tw['text'].lower() )\
                .map(self._score)\
                .map(lambda sc: (1, sc))\
                .reduceByKey(lambda cnt1, cnt2: cnt1+cnt2)\
                .collect()

        return tweets[0][1]


def get_data(sc):

    with open('/home/han/.api_key/awsaccesskey.json') as f:
        key= json.load(f)

        access= key['access-key']
        secret = key['secret-access-key']


    if hasattr(ssl, '_create_unverified_context'):
       ssl._create_default_https_context = ssl._create_unverified_context


    conn = boto.connect_s3()
    b = conn.get_bucket('han.tweets.bucket')
    for i, key in enumerate(b.get_all_keys()):
        print i ,'s3n://'+access+':'+secret +'@han.'+key.name
        if i == 0:
            data = sc.textFile('s3n://'+access+':'+secret +'@han.tweets.bucket/'+key.name)
        if i == 3:
            print key
            break
        else:
            temp_data = sc.textFile('s3n://'+access+':'+secret +'@han.'+key.name)
            data = data.union(data)
    return data

# %%
data = sc.textFile('s3n://'+access+':'+secret +'@han.tweets.08/twitter_dump.txt)
WP = WordPredictor()
WP.fit(data)
WP.predict('I think this is a ')

# %%
link ='s3n://han.tweets.08/twitterdump.txt'

# %%
data = sc.textFile(link)

# %%
data.count()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-24-0106b6ff8a89> in <module>()
# ----> 1 data.count()
#
# /usr/local/spark/python/pyspark/rdd.pyc in count(self)
#    1002         3
#    1003         """
# -> 1004         return self.mapPartitions(lambda i: [sum(1 for _ in i)]).sum()
#    1005
#    1006     def stats(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in sum(self)
#     993         6.0
#     994         """
# --> 995         return self.mapPartitions(lambda x: [sum(x)]).fold(0, operator.add)
#     996
#     997     def count(self):
#
# /usr/local/spark/python/pyspark/rdd.pyc in fold(self, zeroValue, op)
#     867         # zeroValue provided to each partition is unique from the one provided
#     868         # to the final reduce call
# --> 869         vals = self.mapPartitions(func).collect()
#     870         return reduce(op, vals, zeroValue)
#     871
#
# /usr/local/spark/python/pyspark/rdd.pyc in collect(self)
#     769         """
#     770         with SCCallSiteSync(self.context) as css:
# --> 771             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     772         return list(_load_from_socket(port, self._jrdd_deserializer))
#     773
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/java_gateway.pyc in __call__(self, *args)
#     833         answer = self.gateway_client.send_command(command)
#     834         return_value = get_return_value(
# --> 835             answer, self.gateway_client, self.target_id, self.name)
#     836
#     837         for temp_arg in temp_args:
#
# /home/han/anaconda2/lib/python2.7/site-packages/py4j/protocol.pyc in get_return_value(answer, gateway_client, target_id, name)
#     308                 raise Py4JJavaError(
#     309                     "An error occurred while calling {0}{1}{2}.\n".
# --> 310                     format(target_id, ".", name), value)
#     311             else:
#     312                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : java.lang.IllegalArgumentException: Invalid hostname in URI s3n://han.tweets.08/twitterdump.txt
# 	at org.apache.hadoop.fs.s3.S3Credentials.initialize(S3Credentials.java:41)
# 	at org.apache.hadoop.fs.s3native.Jets3tNativeFileSystemStore.initialize(Jets3tNativeFileSystemStore.java:50)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invokeMethod(RetryInvocationHandler.java:85)
# 	at org.apache.hadoop.io.retry.RetryInvocationHandler.invoke(RetryInvocationHandler.java:62)
# 	at org.apache.hadoop.fs.s3native.$Proxy13.initialize(Unknown Source)
# 	at org.apache.hadoop.fs.s3native.NativeS3FileSystem.initialize(NativeS3FileSystem.java:234)
# 	at org.apache.hadoop.fs.FileSystem.createFileSystem(FileSystem.java:1446)
# 	at org.apache.hadoop.fs.FileSystem.access$200(FileSystem.java:67)
# 	at org.apache.hadoop.fs.FileSystem$Cache.get(FileSystem.java:1464)
# 	at org.apache.hadoop.fs.FileSystem.get(FileSystem.java:263)
# 	at org.apache.hadoop.fs.Path.getFileSystem(Path.java:187)
# 	at org.apache.hadoop.mapred.FileInputFormat.listStatus(FileInputFormat.java:176)
# 	at org.apache.hadoop.mapred.FileInputFormat.getSplits(FileInputFormat.java:208)
# 	at org.apache.spark.rdd.HadoopRDD.getPartitions(HadoopRDD.scala:199)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.rdd.MapPartitionsRDD.getPartitions(MapPartitionsRDD.scala:35)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.api.python.PythonRDD.getPartitions(PythonRDD.scala:58)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:239)
# 	at org.apache.spark.rdd.RDD$$anonfun$partitions$2.apply(RDD.scala:237)
# 	at scala.Option.getOrElse(Option.scala:120)
# 	at org.apache.spark.rdd.RDD.partitions(RDD.scala:237)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:1929)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:927)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:150)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:111)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:316)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:926)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:405)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:497)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:231)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:381)
# 	at py4j.Gateway.invoke(Gateway.java:259)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:133)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:209)
# 	at java.lang.Thread.run(Thread.java:745)

# %%
df =pd.DataFrame(columns = ['foo', 'bar'], index = ['test1', 'test2'])

# %%
df.ix['test1']['foo'] =1

# %%
tt = df.to_sparse(fill_value=0)

# %%
df.ix['test2']['bar'] = 1

# %%
df.to_sparse(fill_value=0)
# Out:
#        foo  bar
# test1    1  NaN
# test2  NaN    1
